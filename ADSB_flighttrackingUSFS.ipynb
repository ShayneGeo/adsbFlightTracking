# %% [markdown]
# # Flight tracking

# %%
# from this tutorial:
# https://www.geodose.com/2020/08/create-flight-tracking-apps-using-python-open-data.html

import requests
import json
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.tile_providers import get_provider,STAMEN_TERRAIN
from bokeh.models import HoverTool,LabelSet,ColumnDataSource
import numpy as np

#FLIGHT TRACKING WITH PYTHON AND OPEN AIR TRAFFIC DATA
#'''
#IMPORT LIBRARY
import requests
import json
import pandas as pd
from bokeh.plotting import figure
from bokeh.models import HoverTool,LabelSet,ColumnDataSource
from bokeh.tile_providers import get_provider, STAMEN_TERRAIN
import numpy as np
from bokeh.server.server import Server
from bokeh.application import Application
from bokeh.application.handlers.function import FunctionHandler

#FUNCTION TO CONVERT GCS WGS84 TO WEB MERCATOR
#DATAFRAME
def wgs84_to_web_mercator(df, lon="long", lat="lat"):
    k = 6378137
    df["x"] = df[lon] * (k * np.pi/180.0)
    df["y"] = np.log(np.tan((90 + df[lat]) * np.pi/360.0)) * k
    return df

#POINT
def wgs84_web_mercator_point(lon,lat):
    k = 6378137
    x= lon * (k * np.pi/180.0)
    y= np.log(np.tan((90 + lat) * np.pi/360.0)) * k
    return x,y

#AREA EXTENT COORDINATE WGS84
lon_min,lat_min=-125.974,30.038
lon_max,lat_max=-68.748,52.214

#COORDINATE CONVERSION
xy_min=wgs84_web_mercator_point(lon_min,lat_min)
xy_max=wgs84_web_mercator_point(lon_max,lat_max)

#COORDINATE RANGE IN WEB MERCATOR
x_range,y_range=([xy_min[0],xy_max[0]], [xy_min[1],xy_max[1]])

#REST API QUERY
user_name='ShayneColoradoStateUniversity'
password='Kirbythedog.123'
url_data='https://'+user_name+':'+password+'@opensky-network.org/api/states/all?'+'lamin='+str(lat_min)+'&lomin='+str(lon_min)+'&lamax='+str(lat_max)+'&lomax='+str(lon_max)

    
#FLIGHT TRACKING FUNCTION
def flight_tracking(doc):
    # init bokeh column data source
    flight_source = ColumnDataSource({
        'icao24':[],'callsign':[],'origin_country':[],
        'time_position':[],'last_contact':[],'long':[],'lat':[],
        'baro_altitude':[],'on_ground':[],'velocity':[],'true_track':[],
        'vertical_rate':[],'sensors':[],'geo_altitude':[],'squawk':[],'spi':[],'position_source':[],'x':[],'y':[],
        'rot_angle':[],'url':[]
    })
    
    # UPDATING FLIGHT DATA
    def update():
        response=requests.get(url_data).json()
        
        #CONVERT TO PANDAS DATAFRAME
        col_name=['icao24','callsign','origin_country','time_position','last_contact','long','lat','baro_altitude','on_ground','velocity',
                  'true_track','vertical_rate','sensors','geo_altitude','squawk','spi','position_source']
       
        flight_data=response['states']
        flight_df=pd.DataFrame(flight_data,columns=col_name) 
        #flight_df=flight_df.loc[:,0:16] 
        #flight_df.columns=col_name
        #####
        #####
        #####
        #insert iaoc24 filter for wildlandfirefighting aircraft
        #flight_df = flight_df[flight_df['icao24'] == "aa3410"]
        #
        #####
        #####
        #####
        
        wgs84_to_web_mercator(flight_df)
        flight_df=flight_df.fillna('No Data')
        
        flight_df['rot_angle']=flight_df['true_track']*-1
        icon_url='https://upload.wikimedia.org/wikipedia/commons/thumb/d/d0/Logo_of_the_United_States_Forest_Service.svg/1200px-Logo_of_the_United_States_Forest_Service.svg.png' #icon url
        flight_df['url']=icon_url
        
        # CONVERT TO BOKEH DATASOURCE AND STREAMING
        n_roll=len(flight_df.index)
        flight_source.stream(flight_df.to_dict(orient='list'),n_roll)
        
    #CALLBACK UPATE IN AN INTERVAL
    doc.add_periodic_callback(update, 5000) #5000 ms/10000 ms for registered user . 

    #PLOT AIRCRAFT POSITION
    p=figure(x_range=x_range,y_range=y_range,x_axis_type='mercator',y_axis_type='mercator',sizing_mode='scale_width',height=290)
    tile_prov=get_provider(STAMEN_TERRAIN)
    p.add_tile(tile_prov,level='image')
    p.image_url(url='url', x='x', y='y',source=flight_source,anchor='center',angle_units='deg',angle='rot_angle',h_units='screen',w_units='screen',w=20,h=20)
    #p.circle('x','y',source=flight_source,fill_color='red',hover_color='yellow',size=10,fill_alpha=0.8,line_width=0)

    #ADD HOVER TOOL AND LABEL
    my_hover=HoverTool()
    my_hover.tooltips=[('Call sign','@callsign'),('Origin Country','@origin_country'),('velocity(m/s)','@velocity'),('Altitude(m)','@baro_altitude')]
    #labels = LabelSet(x='x', y='y', text='callsign', level='glyph',
    #        x_offset=5, y_offset=5, source=flight_source, render_mode='canvas',background_fill_color='white',text_font_size="0pt")
    
    labels = LabelSet(x='x', y='y', text='callsign', level='glyph',
                      x_offset=5, y_offset=5, source=flight_source, background_fill_color='white', text_font_size="0pt")
    p.add_tools(my_hover)
    p.add_layout(labels)
    
    doc.title='USFS FLIGHT TRACKING'
    doc.add_root(p)
    
# SERVER CODE
PORT = 4001
apps = {'/': Application(FunctionHandler(flight_tracking))}
server = Server(apps, port=PORT) #define an unused port
server.start()
#localhost:8084
print(f"localhost:{PORT}    paste into new web browser")
# Out:
# localhost:4001    paste into new web browser
# BokehDeprecationWarning: 'tile_providers module' was deprecated in Bokeh 3.0.0 and will be removed, use 'add_tile directly' instead.
# BokehDeprecationWarning: 'get_provider' was deprecated in Bokeh 3.0.0 and will be removed, use 'add_tile directly' instead.

# %% [markdown]
# ### IAOC24 codes for 'most' usfs contracted aircraft

# %%
#https://fireaviation.com/tag/t-01/
#https://registry.faa.gov/aircraftinquiry/Search/NNumberInquiry

# IAOC24 codes for most USFS waterbombers
IAOC24_CODES = ["C00E3E","C07CB2","A7D27A","A69072","A11CBB","A7F642","A9926A","AB79CC","A3F3AC","A3F763","A442AA","A85052",
                "A4EA6D","A380E6","A4B460","A47CBC","A48A3A","A47197","A46DE0","A4C031","A07F21",
               "A380E6","A4B50C","A0956B","A2F996","A2FD4D","A30104","A304BB","A30872","A46DE0","A47CBC","A48A3A","A47197",
                "A5CD6C","A5D123","A5D4DA","AD66E3","ADC0C4","AAFD0B","A5C9B5","A8215E","A19DA0", "A2B7FD"]

IAOC24_CODES = [code.lower() for code in IAOC24_CODES]
print(IAOC24_CODES)
print(len(IAOC24_CODES))

# %% [markdown]
# ### ATU drop data

# %%
from datetime import datetime
from datetime import datetime, timedelta
import pandas as pd

data = pd.read_csv("C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\ATUData\\ATU_2017_2021_1mile_ALL.txt", sep=",", header=0)

print(list(data.columns))
print(len(data))

# %% [markdown]
# ### Tail numbers (Not actually tail number) Tail number from https://fireaviation.com/tag/t-01/ and other sources

# %%
import pandas as pd

# Group the data by "Tail_Numbe" and get the unique values
unique_tail_numbers = data.groupby("Tail_Numbe").size().reset_index(name="Count")

# Print the unique tail numbers and their associated count (number of drops)
print(unique_tail_numbers)

# %% [markdown]
# ### Function to map tail numbers to ADSB codes

# %%
def map_tail_number_to_adsb_code(tail_number):
    if tail_number == "T-01":
        return "a5cd6c"
    elif tail_number == "T-02":
        return "a5d123"
    elif tail_number == "T-03":
        return "a5d4da"
    elif tail_number == "T-05":
        return "ad66e3"
    elif tail_number == "T-06":
        return "adc0c4"
    elif tail_number == "T-07":
        return "aafd0b"
    elif tail_number == "T-10":
        return "a5c9b5"
    elif tail_number == "T-101":
        return "a2f996"
    elif tail_number == "T-102":
        return "a2fd4d"
    elif tail_number == "T-103":
        return "a30104"
    elif tail_number == "T-104":
        return "a304bb"
    elif tail_number == "T-105":
        return "a30872"
    elif tail_number == "T-107":
        return "a30fe0"
    elif tail_number == "T-12":
        return "a5d891"
    elif tail_number == "T-131":
        return "a07f21"
    elif tail_number == "T-132":
        return "a4c031"
    elif tail_number == "T-133":
        return "a4b50c"
    elif tail_number == "T-137":
        return "a0956b"
    elif tail_number == "T-14":
        return "a8215e"
    elif tail_number == "T-142":
        return "a19da0"
    elif tail_number == "T-15":
        return "a2b7fd"
    elif tail_number == "T-152":
        return "ac75f9"
    elif tail_number == "T-16":
        return "a5dfff"
    elif tail_number == "T-160":
        return "ab79cc"
    elif tail_number == "T-161":
        return "a3f3ac"
    elif tail_number == "T-162":
        return "a3f763"
    elif tail_number == "T-163":
        return "a42299"
    elif tail_number == "T-164":
        return "a442aa"
    elif tail_number == "T-166":
        return "c07cb2"
    elif tail_number == "T-167":
        return "a85052"
    elif tail_number == "T-168":
        return "a4ea6d"
    elif tail_number == "T-169":
        return "a380e6"
    elif tail_number == "T-210":
        return "a4b460"
    elif tail_number == "T-260":
        return "a47cbc"
    elif tail_number == "T-261":
        return "a48a3a"
    elif tail_number == "T-262":
        return "a47197"
    elif tail_number == "T-263":
        return "a46de0"
    elif tail_number == "T-40":
        return "A9A086"
    elif tail_number == "T-41":
        return "NA"
    elif tail_number == "T-44":
        return "c00e3e"
    elif tail_number == "T-910":
        return "a7f642"
    elif tail_number == "T-911":
        return "a11cbb"
    elif tail_number == "T-912":
        return "a69072"
    elif tail_number == "T-914":
        return "a7d27a"
    elif tail_number == "T-944":
        return "NA"
    elif tail_number == "N130CG":
        return "a07b6a"
    else:    
        return "UNKNOWN_ADSB_CODE"

# Create a new column "adsbCODE" based on the values in the "Tail_Numbe" column
data["adsbCODE"] = data["Tail_Numbe"].apply(lambda x: map_tail_number_to_adsb_code(x))

# %% [markdown]
# ### Create columns to define the start and end of the query (identify the space-time bounding box)

# %%
data.UTCdateTim = data.UTCdateTim.str[:-4]

#print(data.UTCdateTim)
data['UTCdateTim']= pd.to_datetime(data['UTCdateTim'])
#data.UTCdateTime2 = datetime.data.UTCdateTim

# this isolates the drop time
time_change = timedelta(minutes=0.25)
data["Time2"] = data.UTCdateTim + time_change
data["Time1"] = data.UTCdateTim - time_change

# this i
time_change2 = timedelta(minutes=3.25)
data["Time2_2"] = data.UTCdateTim + time_change2
data["Time1_2"] = data.UTCdateTim - time_change2

# define bounding box
data["Latitude1PLUS"] = data.Latitude1+0.02
data["Latitude1MINUS"] = data.Latitude1-0.02

data["Longitude1PLUS"] = data.Longitude1+0.02
data["Longitude1MINUS"] = data.Longitude1-0.02

dataLatitude1PLUS =data["Latitude1PLUS"].tolist()
dataLatitude1MINUS =data["Latitude1MINUS"].tolist()

dataLongitude1PLUS =data["Longitude1PLUS"].tolist()
dataLongitude1MINUS =data["Longitude1MINUS"].tolist()

dataLongitude1 =  data.Longitude1.tolist()
dataLatitude1 = data.Latitude1.tolist()

# 15 seconds prior to and post start of drop
datetime1 = data.Time1.tolist()
datetime2 = data.Time2.tolist()

# 3 minutes prior to and after the start of the drop (for non-drop samples)
datetime1_2 = data.Time1_2.tolist()
datetime2_2 = data.Time2_2.tolist()

import pandas as pd
import numpy as np
data=data.replace(regex=[':'], value='_')
data=data.replace(regex=['-'], value='_')
data=data.replace(regex=[' '], value='')

data_DropID = data.Drop_ID1.tolist()
adsbCODES = data.adsbCODE.tolist()

# Altitude from feet to meters
data["AltMeter1"] = data["AltFeet1"]*0.3048
data_ALT = data["AltMeter1"]+200
data_ALT = data_ALT.tolist()
len(data)

# %% [markdown]
# # Opensky - collect data - https://opensky-network.org/

# %%
# this is very slow - please excuse the slow pace

from pyopensky import OpenskyImpalaWrapper
from osgeo import ogr
from osgeo import osr
import csv

opensky = OpenskyImpalaWrapper()

for i in range(len(data_DropID)):
    print(i)
    
    # Perform a query with ICAO filter
    df = opensky.query(
        type="adsb",
        #start="2017-06-01 13:00:00",
        #end="2017-07-01 13:00:10",
        #start="2022-06-01",
        #end="2022-08-01",
        start = datetime1[i],
        end = datetime2[i],
        #[lat1, lon1, lat2, lon2]
        #bound=[data.Longitude1MINUS[i],data.Longitude1PLUS[i],data.Latitude1MINUS[i],data.Latitude1PLUS[i]],
        bound=[dataLatitude1MINUS[i],dataLongitude1MINUS[i],dataLatitude1PLUS[i],dataLongitude1PLUS[i]],
        #icao24 = ["a07b6a"]
        icao24 = adsbCODES[i]#IAOC24_CODES#['c00e3e', 'c07cb2', 'a7d27a', 'a69072', 'a11cbb', 'a7f642', 'a9926a', 'ab79cc', 'a3f3ac', 'a3f763', 'a442aa', 'a85052', 'a4ea6d', 'a380e6', 'a4b460', 'a47cbc', 'a48a3a', 'a47197', 'a46de0', 'a4c031', 'a07f21', 'a380e6', 'a4b50c', 'a0956b', 'a2f996', 'a2fd4d', 'a30104', 'a304bb', 'a30872', 'a46de0', 'a47cbc', 'a48a3a', 'a47197', 'a5cd6c', 'a5d123', 'a5d4da', 'ad66e3', 'adc0c4', 'aafd0b', 'a5c9b5', 'a8215e', 'a19da0', 'a2b7fd']
    )
    
    if df is not None:
        #df = df[df["geoaltitude"]<data_ALT[i]]
        
        # this filters the data and ensure there is continuous quality data. The main issue I was facing was limited data availability, 
        # particularly in low elevation mountainous regions with limited ADSB coverage by OpenSky
        # this will drastically limit the avalible data
        if (df['lastposupdate'].nunique() > (len(df)-15)) is True and (df['icao24'].nunique() == 1) is True and (len(df) > 25) is True:

        #if (df['icao24'].nunique() == 1) is True:

            icaocode24 = df['icao24']
            print("itsUniqueEnough")
            df2 = df.dropna(subset = ["lat"])          # Apply dropna() function to remove missing lat lon 
            if len(df2) > 0:
                filepathcsv = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\"+data_DropID[i]+".csv"
                df2.to_csv(filepathcsv)
                filepathshp = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\"+data_DropID[i]+".shp"
                driver = ogr.GetDriverByName("ESRI Shapefile")
                data_src = driver.CreateDataSource(filepathshp)
                srs = osr.SpatialReference()
                srs.ImportFromEPSG(4326)# 4326 = wgs84
                layer = data_src.CreateLayer(filepathshp, 
                                             srs, 
                                             geom_type = ogr.wkbPoint)

                #Create attribute fields from OpenSky
                field_name = ogr.FieldDefn("time", ogr.OFTString)
                field_name.SetWidth(50)
                layer.CreateField(field_name)
                layer.CreateField(ogr.FieldDefn("lon", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lat", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("velocity", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("heading", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("vertrate", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("callsign", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("onground", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("alert", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("spi", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("squawk", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("baro", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("geo", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lastpos", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lastcon", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("hour", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("icao24", ogr.OFTString))
  
                with open(filepathcsv, "r") as csv_file:
                    csv_reader = csv.reader(csv_file)
                    next(csv_reader)
                    for row in csv_reader:        
                        feature = ogr.Feature(layer.GetLayerDefn())
                        feature.SetField("time", row[1])
                        feature.SetField("lon", row[4])
                        feature.SetField("lat", row[3])
                        feature.SetField("velocity", row[5])
                        feature.SetField("heading", row[6])
                        feature.SetField("vertrate", row[7])
                        feature.SetField("callsign", row[8])
                        feature.SetField("onground", row[9])
                        feature.SetField("alert", row[10])
                        feature.SetField("spi", row[11])
                        feature.SetField("squawk", row[12])
                        feature.SetField("baro", row[13])
                        feature.SetField("geo", row[14])
                        feature.SetField("lastpos", row[15])
                        feature.SetField("lastcon", row[16])
                        feature.SetField("hour", row[17])
                        feature.SetField("icao24", row[2])

                        #Create point geometry
                        point = ogr.Geometry(ogr.wkbPoint)
                        point.AddPoint(float(row[4]), float(row[3]))

                        #Create the feature and set the values 
                        feature.SetGeometry(point)
                        layer.CreateFeature(feature)
                        # reset features for next row
                        feature = None
                data_src = None
            
            ##
            dfLong = opensky.query(
                type="adsb",
                #start="2017-06-01 13:00:00",
                #end="2017-07-01 13:00:10",
                #start="2022-06-01",
                #end="2022-08-01",
                start = datetime1_2[i],
                end = datetime2_2[i],
                #[lat1, lon1, lat2, lon2]
                #bound=[data.Longitude1MINUS[i],data.Longitude1PLUS[i],data.Latitude1MINUS[i],data.Latitude1PLUS[i]],
                #bound=[dataLatitude1MINUS[i],dataLongitude1MINUS[i],dataLatitude1PLUS[i],dataLongitude1PLUS[i]],
                icao24 = icaocode24
                )
            
            df2_long = dfLong.dropna(subset = ["lat"])          # Apply dropna() function to remove missing lat lon 
            if len(df2_long) > 0:
                filepathcsv = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\longerversion\\"+data_DropID[i]+".csv"
                df2_long.to_csv(filepathcsv)
                filepathshp = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\longerversion\\"+data_DropID[i]+".shp"
                driver = ogr.GetDriverByName("ESRI Shapefile")
                data_src = driver.CreateDataSource(filepathshp)
                srs = osr.SpatialReference()
                srs.ImportFromEPSG(4326)# 4326 = wgs84
                layer = data_src.CreateLayer(filepathshp, 
                                             srs, 
                                             geom_type = ogr.wkbPoint)

                #Create attribute fields from OpenSky
                field_name = ogr.FieldDefn("time", ogr.OFTString)
                field_name.SetWidth(50)
                layer.CreateField(field_name)
                layer.CreateField(ogr.FieldDefn("lon", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lat", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("velocity", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("heading", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("vertrate", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("callsign", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("onground", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("alert", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("spi", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("squawk", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("baro", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("geo", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lastpos", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lastcon", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("hour", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("icao24", ogr.OFTString))

                with open(filepathcsv, "r") as csv_file:
                    csv_reader = csv.reader(csv_file)
                    next(csv_reader)
                    for row in csv_reader:        
                        feature = ogr.Feature(layer.GetLayerDefn())
                        feature.SetField("time", row[1])
                        feature.SetField("lon", row[4])
                        feature.SetField("lat", row[3])
                        feature.SetField("velocity", row[5])
                        feature.SetField("heading", row[6])
                        feature.SetField("vertrate", row[7])
                        feature.SetField("callsign", row[8])
                        feature.SetField("onground", row[9])
                        feature.SetField("alert", row[10])
                        feature.SetField("spi", row[11])
                        feature.SetField("squawk", row[12])
                        feature.SetField("baro", row[13])
                        feature.SetField("geo", row[14])
                        feature.SetField("lastpos", row[15])
                        feature.SetField("lastcon", row[16])
                        feature.SetField("hour", row[17])
                        feature.SetField("icao24", row[2])


                        #Create point geometry
                        point = ogr.Geometry(ogr.wkbPoint)
                        point.AddPoint(float(row[4]), float(row[3]))

                        #Create the feature and set the values 
                        feature.SetGeometry(point)
                        layer.CreateFeature(feature)
                        # reset features for next row
                        feature = None
                data_src = None

# %% [markdown]
# # Drop data height AGL - GEE

# %%
import os
ee.Initialize(project = 'ee-magstadt')
#input_folder = pathshp
input_folder = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\"

output_folder_short = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\outputdataDROP\\"

# Loop over all shapefiles in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith(".shp"):
        print("Processing:", filename)
        # Construct input and output file paths
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder_short, filename[:-4] + ".csv")  # Remove ".shp" from input filename and add ".csv"
        
        # Run the existing script with the input and output file paths
        import ee
        import geemap
        import pandas as pd
        import time

        try:
            start_time = time.time()

            ee_fc = geemap.shp_to_ee(input_path)

            # Load the 3DEP dataset  and others and filter by the extent of the points
            dem = ee.Image("USGS/3DEP/10m").clip(ee_fc.geometry().bounds())

            # Extract data for each image at appropriate scale
            terrain_fc = ee.Terrain.products(dem).sampleRegions(collection=ee_fc, scale=10.2)

            # Convert the elevation and terrain product data to Pandas DataFrames
            terrain_df = geemap.ee_to_pandas(terrain_fc)

            # Drop rows with missing values
            df_sample = terrain_df.dropna()

            # Calculate height AGL
            baro_altitude = df_sample['geo']
            elevation = df_sample['elevation']
            height_AGL = baro_altitude - elevation
            df_sample['heightAGL'] = height_AGL

            # Export as CSV
            df_sample.to_csv(output_path, index=False)

            print("Completed:", filename)
        except Exception as e:
            print("Error occurred:", e)
            continue

# %% [markdown]
# # Non-drop/drop height AGL - GEE

# %%
ee.Initialize(project = 'ee-magstadt')

#input_folder = pathshplongerversion
input_folder = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\longerversion\\"

output_folder_long = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\outputdataDROPLONG\\"

# Loop over all shapefiles in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith(".shp"):
        print("Processing:", filename)
        # Construct input and output file paths
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder_long, filename[:-4] + ".csv")  # Remove ".shp" from input filename and add ".csv"
        
        # Run the existing script with the input and output file paths
        import ee
        import geemap
        import pandas as pd
        import time

        try:
            start_time = time.time()

            ee_fc = geemap.shp_to_ee(input_path)

            # Load the 3DEP dataset  and others and filter by the extent of the points
            dem = ee.Image("USGS/3DEP/10m").clip(ee_fc.geometry().bounds())

            # Extract data for each image at appropriate scale
            terrain_fc = ee.Terrain.products(dem).sampleRegions(collection=ee_fc, scale=10.2)

            # Convert the elevation and terrain product data to Pandas DataFrames
            terrain_df = geemap.ee_to_pandas(terrain_fc)

            # Drop rows with missing values
            df_sample = terrain_df.dropna()

            # Calculate height AGL
            baro_altitude = df_sample['geo']
            elevation = df_sample['elevation']
            height_AGL = baro_altitude - elevation
            df_sample['heightAGL'] = height_AGL

            # Export as CSV
            df_sample.to_csv(output_path, index=False)

            print("Completed:", filename)
        except Exception as e:
            print("Error occurred:", e)
            continue

# %% [markdown]
# # Drop Samples (only 937 drop samples were obtained from Opensky)

# %%
import pandas as pd
import numpy as np
import glob

# Directory path
dir_path = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\outputdataDROP\\"

# Get list of CSV files
filenames = glob.glob(dir_path + "*.csv")

# Initialize list to store data arrays
data = []
included_files = []

# Loop through each file
for filename in filenames:
    try:
        # Count number of rows in the file
        num_rows = sum(1 for line in open(filename))
        
        # Skip files with less than 26 rows
        if num_rows < 26:
            continue
        
        # Read the last 25 rows of specific columns
        df = pd.read_csv(filename, usecols=[4, 8, 21], nrows=25, skiprows=num_rows-26)
        
        # Convert dataframe to numpy array
        arr = df.values.astype(float)
        
        # Append array to data list
        data.append(arr)
        
        # Store filename in included_files list
        included_files.append(filename)
    except Exception as e:
        print(f"Error processing file {filename}: {e}")

# Check if data was found
if len(data) == 0:
    print("No data found")
else:
    # Stack arrays along the first axis
    array1 = np.stack(data, axis=0)
    print("Shape of array:", array1.shape)
    print("\nList of CSV files included:")
    for file in included_files:
        print(file)
# Out:
# Shape of array: (937, 25, 3)
#
# List of CSV files included:
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_126_23_38_59.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_131_18_25_42.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_137_20_02_44.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_137_20_07_24.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_142_22_22_42.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_142_22_33_59.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_155_23_41_03.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_157_20_39_30.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_160_17_22_50.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_160_18_18_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_160_18_19_04.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_160_19_16_51.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_160_20_07_11.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_160_22_20_04.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_161_18_04_30.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_188_02_59_55.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_188_03_02_11.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_189_22_38_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_189_22_42_19.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_217_22_32_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_217_22_35_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_245_21_24_16.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_245_21_27_11.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_245_21_31_07.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_250_23_44_36.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_251_00_30_45.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_263_21_20_24.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_263_21_21_49.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_263_21_53_26.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_264_19_37_06.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_281_23_44_01.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_282_16_59_31.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N130CG_2019_282_17_55_24.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N131CG_2021_137_23_24_04.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N131CG_2021_138_00_28_03.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N131CG_2021_138_00_31_27.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N131CG_2021_156_23_29_00.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N131CG_2021_157_01_17_16.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N131CG_2021_157_01_19_34.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N131CG_2021_161_22_56_10.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N131CG_2021_200_22_36_28.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N131CG_2021_200_23_51_00.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N131CG_2021_200_23_54_42.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_215_20_27_48.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_215_21_47_41.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_215_23_21_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_215_23_25_32.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_216_00_09_09.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_216_00_54_32.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_216_01_33_09.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_218_20_53_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_218_20_59_32.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_219_17_08_53.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_226_23_32_07.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_227_00_32_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_227_01_16_53.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_227_21_03_31.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_227_21_09_46.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_227_21_59_07.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_227_22_02_22.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_228_01_55_32.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_228_01_58_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_233_20_29_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_233_20_32_59.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_233_21_49_05.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_250_16_27_28.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_250_16_30_40.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_250_19_03_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_250_20_08_14.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_251_22_55_40.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_255_00_52_23.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_255_22_12_17.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_255_23_06_49.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_256_00_05_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_258_00_43_11.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_260_17_24_48.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_264_23_14_08.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_265_01_27_50.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_265_17_22_19.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_269_21_56_29.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2020_301_00_09_20.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2021_205_00_40_30.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2021_285_00_57_18.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2021_285_01_00_32.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2021_285_01_02_56.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N137CG_2021_285_01_05_08.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_157_21_35_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_157_23_04_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_157_23_12_54.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_181_20_24_44.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_181_21_07_02.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_191_18_10_38.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_191_18_14_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_191_19_15_35.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_229_21_46_03.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_260_17_18_00.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_262_22_04_01.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_262_23_54_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_264_20_02_49.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_264_22_42_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_265_17_16_19.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_266_19_34_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_273_21_14_39.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_273_21_49_59.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_277_00_15_01.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_277_01_03_36.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_277_01_03_44.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2020_300_22_27_11.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2021_087_17_01_38.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2021_087_17_03_56.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2021_087_17_05_47.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2021_089_18_03_44.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2021_089_21_06_27.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2021_129_20_48_44.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2021_129_21_38_33.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2021_129_21_41_19.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2021_129_22_32_22.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N291EA_2021_129_23_11_47.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N292EA_2020_185_23_43_17.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N292EA_2020_290_22_22_06.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N292EA_2020_293_00_20_24.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N292EA_2021_128_18_32_54.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N292EA_2021_230_00_44_54.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N292EA_2021_236_19_03_11.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N292EA_2021_241_00_57_28.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2020_173_19_12_18.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2020_173_20_13_03.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2020_173_21_08_07.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2020_177_22_57_46.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2020_266_21_10_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2020_290_23_57_22.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2020_291_00_03_48.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2020_300_21_42_39.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2020_338_23_06_52.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2020_359_16_10_02.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2020_359_21_42_41.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2020_359_22_31_45.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2020_359_23_22_27.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2021_156_00_30_40.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2021_156_23_31_52.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2021_157_00_43_49.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2021_160_01_50_52.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2021_285_01_48_11.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2021_285_01_49_51.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2021_285_01_51_31.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N293EA_2021_285_01_53_20.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_153_00_30_01.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_153_00_32_29.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_157_02_18_00.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_157_22_53_55.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_157_23_37_41.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_158_23_00_22.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_159_01_34_27.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_159_02_13_15.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_159_02_50_35.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_164_19_29_35.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_164_19_55_25.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_164_20_24_32.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_164_20_55_23.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_164_21_27_56.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_164_21_29_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_164_22_10_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_180_03_51_36.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_181_22_24_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_182_01_50_00.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_182_01_52_50.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_186_21_28_40.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_186_21_35_07.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_232_22_30_05.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_232_23_45_01.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_232_23_47_29.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_233_00_57_43.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2020_237_01_24_37.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2021_087_18_24_29.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N294EA_2021_184_22_30_46.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_172_22_12_19.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_172_23_09_55.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_173_00_05_42.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_173_00_59_42.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_173_01_51_06.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_173_02_43_33.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_181_20_50_39.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_249_22_48_35.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_249_22_50_23.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_250_00_13_10.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_250_01_18_06.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_250_17_09_28.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_250_19_37_42.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_250_20_49_31.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_257_01_14_34.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_257_01_57_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_258_00_10_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_258_01_03_19.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_258_02_10_26.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_259_00_42_47.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_259_01_32_16.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_259_17_10_42.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_259_17_48_34.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_262_21_48_43.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_262_22_58_05.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_264_20_37_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_264_22_51_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_265_23_05_38.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_291_22_50_00.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_291_23_21_31.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_293_00_36_02.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_293_21_43_28.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2020_298_22_09_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2021_129_18_05_22.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2021_129_18_50_21.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2021_129_19_48_02.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2021_129_20_29_37.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2021_129_21_17_10.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2021_129_22_04_18.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2021_130_23_38_43.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2021_131_00_18_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2021_131_01_06_55.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2021_137_21_18_53.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2021_137_22_19_31.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2021_137_23_10_01.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2021_137_23_56_55.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2021_241_16_29_32.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N295EA_2021_241_16_32_19.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_181_22_19_23.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_229_22_08_25.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_251_16_07_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_251_23_40_54.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_252_23_00_55.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_253_15_46_02.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_253_16_58_22.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_253_17_02_36.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_254_00_27_33.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_254_01_22_30.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_255_21_49_41.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_255_22_36_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_256_00_17_45.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_257_20_52_37.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_257_20_54_37.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_258_00_50_43.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_258_01_49_24.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_260_20_02_34.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_262_18_41_59.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_262_19_32_25.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_262_20_39_01.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_262_23_23_10.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_264_22_47_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_265_01_21_56.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_290_23_41_38.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_293_16_41_52.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2020_293_16_44_54.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\N297EA_2021_276_22_08_51.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_139_19_10_16.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_144_20_08_53.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_144_20_15_55.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_151_01_06_19.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_151_01_11_22.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_151_01_20_26.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_151_01_24_54.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_151_21_57_47.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_152_01_13_02.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_152_01_15_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_152_01_17_29.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_152_01_19_52.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_154_02_37_21.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_154_02_40_37.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_164_02_16_14.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_168_21_45_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_168_22_54_55.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_169_00_40_18.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_173_02_01_55.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_173_02_04_42.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_173_02_14_26.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_181_23_03_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_181_23_08_54.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_182_01_20_31.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_200_00_40_05.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_200_00_43_41.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_200_00_47_18.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_200_00_50_08.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_293_22_57_17.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2020_293_22_59_22.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2021_156_00_04_44.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2021_156_00_07_36.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2021_157_00_02_40.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2021_157_02_10_25.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2021_157_02_13_05.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2021_157_02_16_19.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2021_237_22_24_42.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2021_240_22_17_15.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2021_240_22_19_25.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2021_241_00_52_03.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2021_241_02_16_48.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2021_241_17_29_59.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2021_241_17_31_34.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2021_241_17_33_56.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2021_241_19_37_33.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2021_286_18_45_17.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T910_2021_288_22_59_40.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2019_178_23_02_45.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2019_178_23_06_27.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2019_203_17_42_31.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2019_203_23_02_42.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2019_203_23_05_35.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2019_204_19_19_33.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2019_204_19_25_30.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2019_204_19_31_14.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2019_235_23_09_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2019_282_01_19_20.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2019_284_23_27_05.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2019_301_15_12_02.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2019_302_01_20_43.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_194_19_54_02.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_214_21_19_03.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_215_18_19_05.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_215_19_13_09.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_215_20_23_25.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_215_21_16_30.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_215_22_11_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_215_23_19_04.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_216_00_16_55.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_216_01_14_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_216_01_17_26.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_216_01_20_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_220_01_37_24.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_220_01_40_55.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_220_02_59_34.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_236_20_15_15.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_236_21_42_20.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_236_21_44_20.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_251_23_07_18.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_254_00_20_38.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_258_18_24_39.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_258_19_52_36.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2020_265_01_11_55.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_167_23_14_21.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_174_18_21_17.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_174_21_36_39.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_177_01_02_28.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_184_18_51_54.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_184_20_04_31.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_184_22_43_56.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_234_19_30_06.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_235_01_14_08.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_235_01_16_46.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_235_02_18_04x.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_236_00_25_15.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_236_02_19_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_239_02_07_22.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_240_23_08_32.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_241_01_50_41.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_241_01_53_02.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T911_2021_241_17_59_34.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_182_20_35_15.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_182_20_39_19.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_220_22_49_30.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_221_01_18_47.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_221_02_28_45.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_221_02_31_53.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_221_17_26_38.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_221_17_34_24.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_221_18_37_21.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_221_20_12_18.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_222_02_42_04.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_222_16_26_03.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_222_16_28_43.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_222_17_39_43.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_222_17_43_59.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_222_21_43_39.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_222_21_52_39.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_223_00_30_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_223_02_00_16.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_223_16_46_42.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_223_17_55_19.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_223_20_04_00.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_223_21_30_02.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_223_21_32_26.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_223_22_53_43.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_224_00_56_01.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_260_18_44_05.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2018_315_19_24_00.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2019_302_17_39_54.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_120_17_38_20.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_123_23_14_11.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_123_23_17_44.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_124_22_45_51.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_124_22_47_47.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_124_22_52_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_124_22_59_40.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_138_22_30_55.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_138_22_34_25.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_139_16_50_34.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_139_16_54_28.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_144_19_24_35.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_144_19_26_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_144_19_29_29.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_144_19_31_52.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_144_19_36_48.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_151_21_16_25.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_151_22_24_51.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_152_00_27_04.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_152_00_34_06.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_152_00_38_29.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_152_00_46_30.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_152_19_39_30.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_152_20_36_44.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_152_20_39_41.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_152_21_47_08.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_152_21_49_36.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_152_21_52_07.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_152_22_45_54.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_152_22_58_35.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_152_23_54_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_154_01_33_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_154_02_31_30.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_154_02_34_19.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_154_02_34_19x.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_167_02_13_32.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_220_18_23_34.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_223_23_03_00.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_224_01_54_43.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_236_21_29_05.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_242_00_44_02.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_260_18_53_47.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_260_20_10_05.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_262_19_10_45.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_262_20_19_06.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_262_21_34_05.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_262_22_48_04.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_262_22_52_05.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_263_00_07_50.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_290_22_05_27.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2020_292_00_01_46.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_153_23_29_51.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_153_23_34_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_182_04_16_33.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_203_02_59_15.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_235_22_41_01.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_236_00_56_45.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_236_02_01_43.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_236_02_01_43x.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_236_19_16_34.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_236_19_19_09.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_236_19_19_09x.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_237_21_06_55.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_238_00_19_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_238_21_34_49.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_240_00_23_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_240_01_18_35.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_240_02_16_39.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_240_02_16_39x.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_241_01_26_37.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_241_01_26_43x.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_241_16_54_41.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_241_17_56_06.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_241_19_13_16.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_242_00_38_27.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_243_00_06_36.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T912_2021_255_01_49_30xx.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_166_02_33_36.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_166_02_33_36x.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_166_02_33_49x.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_166_23_00_56.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_168_01_47_20.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_168_01_52_22.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_168_01_56_56.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_170_17_12_56.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_172_21_26_44.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_173_00_00_04.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_173_00_02_47.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_173_01_10_44.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_173_01_13_31.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_173_02_23_24.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_173_18_39_48.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_173_18_43_19.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_173_19_54_52.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_173_19_58_50.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_173_20_03_02.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_173_20_06_38.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_173_20_10_08.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_173_21_18_49.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_173_22_35_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_175_23_31_28.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_176_00_43_51.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_177_22_48_34.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_177_22_54_21.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_188_03_35_24.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_194_19_52_14.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_194_19_57_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_194_21_22_03.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_203_23_16_03.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_212_23_59_35.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_213_00_05_11.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_215_20_39_00.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_215_21_38_14.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_215_22_32_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_215_23_42_44.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_216_00_43_48.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_216_00_46_00.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_216_01_42_53.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_216_01_46_18.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_216_17_52_48.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_216_18_55_00.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_216_19_49_21.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_217_17_46_27.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_217_17_50_19.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_217_18_37_08.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_217_18_41_15.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_217_20_27_40.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_219_00_10_09.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_224_02_38_50.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_235_20_57_27.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_235_21_02_04.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_235_21_07_56.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_235_22_45_05.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_235_22_47_35.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_236_19_45_25.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_245_02_33_11.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_250_17_40_08.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_250_21_25_40.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_250_22_52_27.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_251_21_47_33.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_252_00_43_51.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_252_23_11_42.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_252_23_15_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_253_22_53_47.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_253_23_55_37.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_254_00_59_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_255_01_27_10.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_255_23_29_23.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_256_00_27_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_256_00_36_25.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T914_2020_257_00_34_32.csv
# ...
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_163_2020_284_22_02_59.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_163_2020_284_22_45_55.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_163_2021_089_22_41_39.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_163_2021_090_00_09_31.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_163_2021_129_20_08_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_163_2021_177_00_33_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_163_2021_184_22_02_45.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_163_2021_184_23_17_21.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_163_2021_230_01_28_16.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_163_2021_236_23_26_53.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_163_2021_237_23_29_47.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_139_15_47_56.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_139_17_03_17.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_139_18_11_53.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_139_19_24_08.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_139_19_30_46.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_144_18_52_49.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_144_19_42_38.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_151_00_43_10.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_151_00_52_28.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_151_01_40_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_151_01_47_41.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_151_23_05_36.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_152_00_02_02.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_152_20_09_11.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_152_20_47_33.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_152_21_42_28.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_152_22_21_59.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_153_01_16_29.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_154_00_04_35.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_170_19_59_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_173_18_32_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_173_19_43_38.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_173_19_47_10.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_173_20_49_42.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_173_21_44_00.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_173_22_47_41.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_196_21_05_10.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_293_16_51_24.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_293_16_55_43.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_293_16_58_29.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2020_301_00_17_14.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2021_236_23_25_27.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2021_240_21_43_06.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2021_240_22_31_09.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2021_240_23_28_18.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_164_2021_273_20_30_18.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2017_290_15_13_43.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2017_290_16_58_55.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2017_290_18_11_49.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2017_290_19_32_45.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2017_290_20_32_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_199_18_21_19.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_212_22_00_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_219_15_57_42.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_219_17_30_18.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_219_18_14_30.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_219_22_14_05.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_219_23_07_52.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_219_23_55_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_220_00_41_39.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_220_01_40_35.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_220_02_33_11.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_222_16_55_44.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_222_18_07_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_222_18_53_45.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_222_22_03_11.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_223_01_05_41.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_223_02_11_11.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_223_16_40_54.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_223_17_51_47.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_223_18_39_20.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_223_21_12_59.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_166_2018_224_00_33_38.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_167_2017_263_23_23_43.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_167_2017_284_17_16_41.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_167_2017_287_22_19_51.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_167_2018_093_21_54_53.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_167_2018_094_16_34_40.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_167_2018_094_18_17_09.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_167_2018_152_18_27_29.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_167_2018_152_18_32_06.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_167_2019_249_16_08_17.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_167_2019_249_18_16_37.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_167_2019_251_18_39_03.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_167_2020_236_17_57_47.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_167_2020_236_18_40_25.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_167_2020_236_20_13_45.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_167_2021_135_23_46_05.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_167_2021_136_00_51_28.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_167_2021_146_22_56_35.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2019_217_02_10_25.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2019_217_02_25_26.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2019_284_15_13_43.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2019_284_22_17_30.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_181_16_36_43.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_181_17_52_48.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_181_22_56_56.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_202_22_05_20.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_203_21_17_21.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_231_22_23_30.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_231_22_26_06.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_231_22_30_35.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_238_17_45_03.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_238_17_47_46.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_238_18_54_37.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_238_19_45_46.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_238_19_48_37.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_238_19_51_41.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_238_20_44_42.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_238_20_47_37.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_238_20_49_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2020_238_20_52_17.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2021_129_20_18_30.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2021_129_21_25_52.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2021_129_22_12_55.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2021_129_23_04_43.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2021_129_23_51_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2021_130_01_15_46.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2021_147_19_21_10.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2021_156_00_49_12.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2021_156_01_57_18.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_168_2021_191_03_27_34.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_169_2021_109_21_16_33.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_169_2021_129_20_05_16.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_169_2021_129_21_12_56.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_169_2021_129_22_21_27.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_169_2021_147_19_10_18.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_169_2021_198_19_22_40.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_169_2021_198_19_37_29.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_169_2021_198_21_22_52.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_169_2021_198_21_28_59.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2019_160_17_17_27.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2019_160_18_15_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2019_203_17_26_11.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2019_203_19_15_34.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2019_203_20_13_10.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2019_203_21_16_34.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2019_206_22_04_47.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2019_207_01_37_59.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2019_207_02_48_42.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2019_249_00_43_21.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2019_258_01_47_27.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2020_181_20_36_52.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2020_181_21_35_10.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2020_181_21_37_30.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2020_238_21_42_31.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2020_290_15_50_56.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2021_254_00_16_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_16_2021_261_20_38_21.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_260_2019_262_21_43_17.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_260_2020_179_21_10_49.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_260_2020_179_22_32_17.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_261_2020_176_01_38_24.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_261_2020_231_00_01_41.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_261_2020_231_01_06_02.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_261_2020_231_01_15_35.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_261_2020_237_17_25_57.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_261_2020_237_17_49_10.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_261_2020_237_19_20_58.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_261_2021_131_01_00_24.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_261_2021_131_01_14_24.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_261_2021_131_01_36_47.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_261_2021_131_01_50_24.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_261_2021_131_02_04_47.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_262_2020_176_01_53_04.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_262_2020_237_18_09_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_262_2021_146_18_55_43.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_263_2020_179_20_52_25.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_263_2020_179_21_11_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_263_2021_104_00_04_44.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_263_2021_131_01_00_05.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_263_2021_131_01_14_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_263_2021_131_01_50_16.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_263_2021_131_02_04_32.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_263_2021_131_18_52_13.csv
# C:\Users\admin-magstadt\Desktop\Data_4_17_2023\outputdataDROP\T_263_2021_131_20_20_13.csv

# %%
# import os

# new_pathway = 'C:\\Users\\admin-magstadt\\Desktop\\ADSBData\\NondropSamplesADSB'

# included_files_end_names = [os.path.basename(file) for file in included_files]
# new_pathway_files = [file for file in os.listdir(new_pathway)]

# for file in new_pathway_files:
#     if file not in included_files_end_names:
#         os.remove(os.path.join(new_pathway, file))

# %%
import pandas as pd
import numpy as np
import glob

#dir_path = output_folder_short
dir_path = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\outputdataDROP\\"
#dir_path = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_3_2023\\"

filenames = glob.glob(dir_path + "*.csv")

data = []

for filename in filenames:
    num_rows = sum(1 for line in open(filename))
    if num_rows < 26:
        #print(f"Skipping {filename}: less than 25 rows")
        continue
    df = pd.read_csv(filename, usecols=[4,8,21], nrows=25, skiprows=num_rows-26)
    arr = df.values.astype(float)
    data.append(arr)

if len(data) == 0:
    print("No data found")
else:
    array1 = np.stack(data, axis=0)
    print(array1.shape)
# Out:
# (937, 25, 3)

# %% [markdown]
# # Non-drop samples - time chunks pre and post drop event

# %%
import pandas as pd
import numpy as np
import glob

dir_path = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\outputdataDROPLONG\\"
filenames = glob.glob(dir_path + "*.csv")

data = []

for filename in filenames:
    num_rows = sum(1 for line in open(filename))
    if num_rows < 51:
        #print(f"Skipping {filename}: less than 51 rows")
        continue
    df = pd.read_csv(filename, usecols=[4, 8, 21], nrows=25)#, skiprows=range(1, 50))
    arr = df.values.astype(float)
    data.append(arr)

if len(data) == 0:
    print("No data found")
else:
    array2 = np.stack(data, axis=0)
    print(array2.shape)
# Out:
# (1170, 25, 3)

# %%
import pandas as pd
import numpy as np
import glob

dir_path = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\outputdataDROPLONG\\"
filenames = glob.glob(dir_path + "*.csv")

data = []

for filename in filenames:
    num_rows = sum(1 for line in open(filename))
    if num_rows < 51:
        #print(f"Skipping {filename}: less than 51 rows")
        continue
    df = pd.read_csv(filename, usecols=[4, 8, 21], nrows=25, skiprows=range(0, 26))
    arr = df.values.astype(float)
    data.append(arr)

if len(data) == 0:
    print("No data found")
else:
    array3 = np.stack(data, axis=0)
    print(array3.shape)
# Out:
# (1170, 25, 3)

# %%
import pandas as pd
import numpy as np
import glob

dir_path = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\outputdataDROPLONG\\"
filenames = glob.glob(dir_path + "*.csv")

data = []

for filename in filenames:
    num_rows = sum(1 for line in open(filename))
    if num_rows < 51:
        #print(f"Skipping {filename}: less than 51 rows")
        continue
    df = pd.read_csv(filename, usecols=[4, 8, 21], nrows=25, skiprows=range(0, 51))
    arr = df.values.astype(float)
    data.append(arr)

if len(data) == 0:
    print("No data found")
else:
    array4 = np.stack(data, axis=0)
    print(array4.shape)
# Out:
# (1170, 25, 3)

# %%
import pandas as pd
import numpy as np
import glob

dir_path = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\outputdataDROPLONG\\"
filenames = glob.glob(dir_path + "*.csv")

data = []

for filename in filenames:
    num_rows = sum(1 for line in open(filename))
    if num_rows < 51:
        #print(f"Skipping {filename}: less than 51 rows")
        continue
    df = pd.read_csv(filename, usecols=[4, 8, 21], nrows=25, skiprows=range(0, 75))
    arr = df.values.astype(float)
    data.append(arr)

if len(data) == 0:
    print("No data found")
else:
    array5 = np.stack(data, axis=0)
    print(array5.shape)
# Out:
# (1170, 25, 3)

# %%
import pandas as pd
import numpy as np
import glob

dir_path = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\outputdataDROPLONG\\"
filenames = glob.glob(dir_path + "*.csv")

data = []

for filename in filenames:
    num_rows = sum(1 for line in open(filename))
    if num_rows < 51:
        #print(f"Skipping {filename}: less than 51 rows")
        continue
    df = pd.read_csv(filename, usecols=[4, 8, 21], nrows=25, skiprows=range(0, 100))
    arr = df.values.astype(float)
    data.append(arr)

if len(data) == 0:
    print("No data found")
else:
    array6 = np.stack(data, axis=0)
    print(array6.shape)
# Out:
# (1170, 25, 3)

# %%
#Backend
import pandas as pd
import numpy as np
import glob

dir_path = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\outputdataDROPLONG\\"
filenames = glob.glob(dir_path + "*.csv")

data = []

for filename in filenames:
    num_rows = sum(1 for line in open(filename))
    if num_rows < 51:
        #print(f"Skipping {filename}: less than 51 rows")
        continue
    df = pd.read_csv(filename, usecols=[4, 8, 21])
    df = df.iloc[-50:-25]
    arr = df.values.astype(float)
    data.append(arr)

if len(data) == 0:
    print("No data found")
else:
    array7 = np.stack(data, axis=0)
    print(array7.shape)
# Out:
# (1170, 25, 3)

# %%
#Backend
import pandas as pd
import numpy as np
import glob

dir_path = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\outputdataDROPLONG\\"
filenames = glob.glob(dir_path + "*.csv")

data = []

for filename in filenames:
    num_rows = sum(1 for line in open(filename))
    if num_rows < 51:
        #print(f"Skipping {filename}: less than 51 rows")
        continue
    df = pd.read_csv(filename, usecols=[4, 8, 21])
    df = df.iloc[-75:-50]
    arr = df.values.astype(float)
    data.append(arr)

if len(data) == 0:
    print("No data found")
else:
    array8 = np.stack(data, axis=0)
    print(array8.shape)
# Out:
# (1170, 25, 3)

# %%
#Backend
import pandas as pd
import numpy as np
import glob

dir_path = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\outputdataDROPLONG\\"
filenames = glob.glob(dir_path + "*.csv")

data = []

for filename in filenames:
    num_rows = sum(1 for line in open(filename))
    if num_rows < 51:
        #print(f"Skipping {filename}: less than 51 rows")
        continue
    df = pd.read_csv(filename, usecols=[4, 8, 21])
    df = df.iloc[-100:-75]
    arr = df.values.astype(float)
    data.append(arr)

if len(data) == 0:
    print("No data found")
else:
    array9 = np.stack(data, axis=0)
    print(array9.shape)
# Out:
# (1170, 25, 3)

# %%
#Backend
import pandas as pd
import numpy as np
import glob

dir_path = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\outputdataDROPLONG\\"
filenames = glob.glob(dir_path + "*.csv")

data = []

for filename in filenames:
    num_rows = sum(1 for line in open(filename))
    if num_rows < 51:
        #print(f"Skipping {filename}: less than 51 rows")
        continue
    df = pd.read_csv(filename, usecols=[4, 8, 21])
    df = df.iloc[-125:-100]
    arr = df.values.astype(float)
    data.append(arr)

if len(data) == 0:
    print("No data found")
else:
    array10 = np.stack(data, axis=0)
    print(array10.shape)
# Out:
# (1170, 25, 3)

# %%
array10.shape
# Out:
# (1170, 25, 3)

# %% [markdown]
# ### stack and combine array

# %%
stacked_array = np.concatenate((array2,array3,array4,array5,array6,array7,array8,array9,array10), axis=0)
print(stacked_array.shape)

combined_array = np.concatenate((array1, stacked_array), axis=0)
print(combined_array.shape)
# Out:
# (10530, 25, 3)
# (11467, 25, 3)

# %% [markdown]
# ### Label and train test split

# %%
from sklearn.model_selection import train_test_split

# Split the data into training, validation,
DROP_label = np.concatenate((np.ones(array1.shape[0]), np.zeros(stacked_array.shape[0])))

train_data, test_data, train_labels, test_labels = train_test_split(combined_array, DROP_label, test_size=0.3, random_state=545)
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size=0.3, random_state=545)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 from sklearn.model_selection import train_test_split
#       3 # Split the data into training, validation,
# ----> 4 DROP_label = np.concatenate((np.ones(array1.shape[0]), np.zeros(stacked_array.shape[0])))
#       6 train_data, test_data, train_labels, test_labels = train_test_split(combined_array, DROP_label, test_size=0.3, random_state=545)
#       7 train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size=0.3, random_state=545)
#
# NameError: name 'stacked_array' is not defined

# %%
DROP_label[10]
# Out:
# 1.0

# %% [markdown]
# ### LSTM

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
def create_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(64, input_shape=input_shape))
    #model.add(Dropout(0.5))
    #model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

input_shape = (train_data.shape[1], train_data.shape[2])
modelRNN = create_lstm_model(input_shape)

history = modelRNN.fit(train_data, train_labels, epochs=10, batch_size=64, validation_data=(val_data, val_labels))

test_loss, test_acc = modelRNN.evaluate(test_data, test_labels)
print('Test accuracy:', test_acc)

# %%
from kerastuner import HyperModel, Hyperband

class LSTMHyperModel(HyperModel):
    def __init__(self, input_shape):
        self.input_shape = input_shape

    def build(self, hp):
        model = Sequential()
        model.add(LSTM(hp.Int('units', min_value=32, max_value=128, step=32), input_shape=self.input_shape))
        model.add(Dropout(hp.Float('dropout', min_value=0.2, max_value=0.6, step=0.1)))
        model.add(Dense(hp.Int('dense_units', min_value=16, max_value=64, step=16), activation='relu'))
        model.add(Dropout(hp.Float('dense_dropout', min_value=0.2, max_value=0.6, step=0.1)))
        model.add(Dense(1, activation='sigmoid'))
        model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
        return model

# %%
hypermodel = LSTMHyperModel(input_shape)
tuner = Hyperband(hypermodel, objective='val_accuracy', max_epochs=10, factor=3)

# %%
from keras.callbacks import Callback

class PrintLogs(Callback):
    def on_epoch_end(self, epoch, logs=None):
        print(f"\nTrial {self.trial.trial_id} Epoch {epoch}")
        print(f"Validation Accuracy: {logs['val_accuracy']:.4f}")
        print(f"Training Accuracy: {logs['accuracy']:.4f}\n")

print_logs = PrintLogs()

tuner.search(train_data, train_labels, epochs=2, batch_size=64, validation_data=(val_data, val_labels), callbacks=[print_logs], overwrite=True)

#tuner.search(train_data, train_labels, epochs=10, batch_size=64, overwrite=True, validation_data=(val_data, val_labels))

# %%
best_model = tuner.get_best_models(num_models=1)[0]

test_loss, test_acc = best_model.evaluate(test_data, test_labels)
print('Test accuracy:', test_acc)

# %% [markdown]
# # 1dcnn

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout


def create_1dcnn_model(input_shape):
    model = Sequential()
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(25, 3)))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

input_shape = (train_data.shape[1], train_data.shape[2])
modelCNN = create_1dcnn_model(input_shape)

history = modelCNN.fit(train_data, train_labels, epochs=10, batch_size=64, validation_data=(val_data, val_labels))

test_loss, test_acc = modelCNN.evaluate(test_data, test_labels)
print('Test accuracy:', test_acc)

# %% [markdown]
# # Predicting NRT - work in progress

# %%
import datetime
import geemap
import ee

# Initialize the Earth Engine library
ee.Initialize(project = 'ee-magstadt')

from pyopensky import OpenskyImpalaWrapper
opensky = OpenskyImpalaWrapper()


# some time during deployment

timestamp = 1600454324
converted_time1 = datetime.datetime.utcfromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')

timestamp2 = 1600454324+30
converted_time2 = datetime.datetime.utcfromtimestamp(timestamp2).strftime('%Y-%m-%d %H:%M:%S')



# Get the current time to test speed
start_time = datetime.datetime.now()

df = opensky.query(
        type="adsb",
        #start="2017-06-01 13:00:00",
        #end="2017-07-01 13:00:10",
        #start="2020-09-18 18:38:44",
        #end="2020-09-18 18:38:54",
        start = str(converted_time1),#datetime.datetime.fromtimestamp(timestamp),
        end = str(converted_time2),
        
        #[lat1, lon1, lat2, lon2]
        #bound=[data.Longitude1MINUS[i],data.Longitude1PLUS[i],data.Latitude1MINUS[i],data.Latitude1PLUS[i]],
        #bound=[dataLatitude1MINUS[i],dataLongitude1MINUS[i],dataLatitude1PLUS[i],dataLongitude1PLUS[i]],
        #icao24 = ["a07b6a"]
        icao24 = ['a30fe0']#adsbCODES[i]#IAOC24_CODES#['c00e3e', 'c07cb2', 'a7d27a', 'a69072', 'a11cbb', 'a7f642', 'a9926a', 'ab79cc', 'a3f3ac', 'a3f763', 'a442aa', 'a85052', 'a4ea6d', 'a380e6', 'a4b460', 'a47cbc', 'a48a3a', 'a47197', 'a46de0', 'a4c031', 'a07f21', 'a380e6', 'a4b50c', 'a0956b', 'a2f996', 'a2fd4d', 'a30104', 'a304bb', 'a30872', 'a46de0', 'a47cbc', 'a48a3a', 'a47197', 'a5cd6c', 'a5d123', 'a5d4da', 'ad66e3', 'adc0c4', 'aafd0b', 'a5c9b5', 'a8215e', 'a19da0', 'a2b7fd']
    )

ee_df = geemap.pandas_to_ee(df, latitude = 'lat', longitude='lon')
# Create a Map and add the Earth Engine object as points
Map = geemap.Map()#center=[38.45, -122.59], zoom=12)
Map.addLayer(ee_df, {'color': 'red'}, 'Aircraft Points')

# Display the map
#Map

# Load the 3DEP dataset  and others and filter by the extent of the points
dem = ee.Image("USGS/3DEP/10m").clip(ee_df.geometry().bounds())

# Extract data for each image at appropriate scale
terrain_fc = ee.Terrain.products(dem).sampleRegions(collection=ee_df, scale=10.2)

# Convert the elevation and terrain product data to Pandas DataFrames
terrain_df = geemap.ee_to_pandas(terrain_fc)

# Drop rows with missing values
df_sample = terrain_df.dropna()

# Calculate height AGL
baro_altitude = df_sample['geoaltitude']
elevation = df_sample['elevation']
height_AGL = baro_altitude - elevation
df_sample['heightAGL'] = height_AGL

# prep data for prediction
subset_array = df_sample[['velocity', 'vertrate', 'heightAGL']].values[:25]
subset_array.shape

# shape it correctly for the model.predict
arrayPRED = np.reshape(subset_array, (1, 25, 3))
#arrayPRED.shape

# Make predictions
prediction = modelCNN.predict(arrayPRED)

# Get the current time again
end_time = datetime.datetime.now()

# Calculate the time difference
time_difference = end_time - start_time

# Print the time difference
print("Time difference:", time_difference)
print(f"prediction of drop is: {prediction}")

# %%
# Display the map
Map
