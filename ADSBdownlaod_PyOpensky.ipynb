# %%
# # May Not Work - use your imagination
#pip install --upgrade pip "C:\Users\admin-magstadt\Downloads\GDAL-3.4.3-cp39-cp39-win_amd64.whl"

# pip install "C:\Users\admin-magstadt\Downloads\pyopensky-1.4-py3-none-any (1).whl"

# #pip install gdal
# #import gdal

# #python.exe -m pip install --upgrade pip
# pip install -e "git+https://github.com/openskynetwork/opensky-api.git#egg=python&subdirectory=python"
# # need credentials
# #pip install pyopensky
# pip install "C:\Users\admin-magstadt\Downloads\GDAL-3.4.3-cp39-cp39-win_amd64.whl"

#pip install "C:\Users\admin-magstadt\Downloads\GDAL-3.4.3-cp39-cp39-win_amd64.whl"
#import GDAL
from pyopensky import OpenskyImpalaWrapper

# %% [markdown]
# ### must install opensky api - This link should work
# ### but may not work give different environment and operating systemm

# %%
# may work :))) -- use your imagination 
# https://github.com/junzis/pyopensky
#pip install pyopensky --upgrade

# %% [markdown]
# ### the following libraries are required - good luck

# %%
from pyopensky import OpenskyImpalaWrapper
from osgeo import ogr
from osgeo import osr
import csv
# Out:
# C:\Users\admin-magstadt\anaconda3\envs\ee\lib\site-packages\osgeo\ogr.py:22: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp

# %% [markdown]
# ### Way to get the current date time

# %%
import datetime
from datetime import timedelta

# Current datetime
now = datetime.datetime.now()
print(now)

# time n minutes ago
time_change = timedelta(minutes=100)
before = now-time_change
print(before)

# %% [markdown]
# ### OpenSkyAPI SIMPLE

# %%
from pyopensky import OpenskyImpalaWrapper

opensky = OpenskyImpalaWrapper()

df = opensky.query(
    type="adsb",
    #start="2018-07-01 13:00:00",
    #end="2018-07-01 13:00:10",
    start="2021-10-12",
    end="2021-10-13",
    #end="2019-10-24",
    #start=before,
    #end=now,
    #bound=[39.1, -122.5, 37.1,-120.5]#,
    bound=[38.6, -121.7, 37.6,-121]#,jup

    #bound=[data.Latitude1MINUS[i],data.Longitude1MINUS[i],data.Latitude1PLUS[i],data.Longitude1PLUS[i]],
    #icao24=["a99318"]
)
df

# %%
df.head()

# %%
if df is not None:
        filepathshpATU = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\SHPfromPython\\scratch_2_13_2023_a99318\\test_2_21_23_3.shp"
        #filepathcsvATU = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\CSVfromPython\\scratch_2_10_2023_short\\"+data_DropID[i]+"_ATUDROP.csv"
        
        filepathcsvNA = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\CSVfromPythonwNA\\scratch_2_10_2023_short\\test_2_21_23_3.csv"
        
        filepathcsv = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\CSVfromPython\\scratch_2_13_2023_a99318\\test_2_21_23_3.csv"
        #filepathcsv = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\CSVfromPython\\scratch_2_13_2023_a99318\\"+data_DropID[i]+".csv"
        
        #filepathshp = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\SHPfromPython\\scratch_2_13_2023_a99318\\"+data_DropID[i]+".shp"
        filepathshp = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\SHPfromPython\\scratch_2_13_2023_a99318\\test_2_21_23_3.shp"

        ### FOR SHAPEFILES OF ATUDROP
        driver = ogr.GetDriverByName("ESRI Shapefile")
        data_src = driver.CreateDataSource(filepathshpATU)
        srs = osr.SpatialReference()
        srs.ImportFromEPSG(4326)# 4326 = wgs84
        layer = data_src.CreateLayer(filepathshpATU, 
                                         srs, 
                                         geom_type = ogr.wkbPoint)

        #Create attribute fields from OpenSky
        field_name = ogr.FieldDefn("data_DropID", ogr.OFTString)
        field_name.SetWidth(50)
        layer.CreateField(field_name)
        layer.CreateField(ogr.FieldDefn("lon", ogr.OFTReal))
        layer.CreateField(ogr.FieldDefn("lat", ogr.OFTReal))
        #layer.CreateField(ogr.FieldDefn("data_DropID", ogr.OFTReal))
       
        feature = ogr.Feature(layer.GetLayerDefn())
        feature.SetField("data_DropID", data_DropID[i])
        feature.SetField("lon", data.Longitude1[i])
        feature.SetField("lat", data.Latitude1[i])
        #feature.SetField("data_DropID", data_DropID[i])
                
        #Create point geometry
        point = ogr.Geometry(ogr.wkbPoint)
        point.AddPoint(float(data.Longitude1[i]), float(data.Latitude1[i]))

        #Create the feature and set the values 
        feature.SetGeometry(point)
        layer.CreateFeature(feature)
        # reset features for next row
        feature = None
        data_src = None
        
        ### END SHAPEFILES OF ATUDROP
        df.to_csv(filepathcsvNA)

        df2 = df.dropna(subset = ["lat"])          # Apply dropna() function to remove missing lat lon 
        if len(df2) > 0:

            df2.to_csv(filepathcsv)
        
            driver = ogr.GetDriverByName("ESRI Shapefile")
            data_src = driver.CreateDataSource(filepathshp)
            srs = osr.SpatialReference()
            srs.ImportFromEPSG(4326)# 4326 = wgs84
            layer = data_src.CreateLayer(filepathshp, 
                                         srs, 
                                         geom_type = ogr.wkbPoint)

            #Create attribute fields from OpenSky
            field_name = ogr.FieldDefn("time", ogr.OFTString)
            field_name.SetWidth(50)
            layer.CreateField(field_name)
            layer.CreateField(ogr.FieldDefn("lon", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("lat", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("velocity", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("heading", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("vertrate", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("callsign", ogr.OFTString))
            layer.CreateField(ogr.FieldDefn("onground", ogr.OFTString))
            layer.CreateField(ogr.FieldDefn("alert", ogr.OFTString))
            layer.CreateField(ogr.FieldDefn("spi", ogr.OFTString))
            layer.CreateField(ogr.FieldDefn("squawk", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("baro", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("geo", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("lastpos", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("lastcon", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("hour", ogr.OFTString))
    
            with open(filepathcsv, "r") as csv_file:
                csv_reader = csv.reader(csv_file)
                next(csv_reader)
                for row in csv_reader:        
                    feature = ogr.Feature(layer.GetLayerDefn())
                    feature.SetField("time", row[1])
                    feature.SetField("lon", row[4])
                    feature.SetField("lat", row[3])
                    feature.SetField("velocity", row[5])
                    feature.SetField("heading", row[6])
                    feature.SetField("vertrate", row[7])
                    feature.SetField("callsign", row[8])
                    feature.SetField("onground", row[9])
                    feature.SetField("alert", row[10])
                    feature.SetField("spi", row[11])
                    feature.SetField("squawk", row[12])
                    feature.SetField("baro", row[13])
                    feature.SetField("geo", row[14])
                    feature.SetField("lastpos", row[15])
                    feature.SetField("lastcon", row[16])
                    feature.SetField("hour", row[17])
     
                    #Create point geometry
                    point = ogr.Geometry(ogr.wkbPoint)
                    point.AddPoint(float(row[4]), float(row[3]))

                    #Create the feature and set the values 
                    feature.SetGeometry(point)
                    layer.CreateFeature(feature)
                    # reset features for next row
                    feature = None
            data_src = None

# %% [markdown]
# ### List of 2017 Helicopter IAOC24 numbers

# %%
# list of all avaliable - IAOC24 codes for the adsb transponders
ListHeli2017 = ["a003d8",	"a00996",	"a00d9f",	"a00df0",	"a011d0",	"a01663",	"a01717",	"a01b0a",	"a01bc9",	"a01d3d",	"a01ee6",
                "a01eef",	"a020f4",	"a0218b",	"a021e6",	"a02232",	"a02234",	"a02460",	"a02504",	"a02585",	"a025e9",	"a02737",
                "a02862",	"a028ac",	"a028af",	"a02ac9",	"a02cb3",	"a02eff",	"a02f59",	"a02f8e",	"a02fbe",	"a03045",	"a030f1",
                "a037d9",	"a03b8f",	"a03b90",	"a03ec5",	"a0427c",	"a0441d",	"a04600",	"a04640",	"a0468f",	"a047d2",	"a047d4",
                "a04b00",	"a04b89",	"a04f40",	"a05158",	"a05213",	"a0521e",	"a054ad",	"a0554a",	"a056e3",	"a05a76",	"a05b11",
                "a05b4b",	"a05ba0",	"a06299",	"a0630e",	"a0633d",	"a06682",	"a06aa7",	"a071ea",	"a07655",	"a078ea",	"a0795d",
                "a080a9",	"a082af",	"a082c0",	"a08852",	"a08de5",	"a08e0f",	"a0919c",	"a09451",	"a09501",	"a09553",	"a0a10e",
                "a0a11c",	"a0a152",	"a0a328",	"a0a6e5",	"a0a818",	"a0aa23",	"a0ab32",	"a0af73",	"a0af86",	"a0b0ea",	"a0b1ad",
                "a0b2a0",	"a0b657",	"a0b6f4",	"a0baab",	"a0be62",	"a0c219",	"a0c5d0",	"a0c89b",	"a0c8d1",	"a0cae6",	"a0cafb",
                "a0d19c",	"a0d90e",	"a0dabf",	"a0e77d",	"a0e7ea",	"a0eba1",	"a0f005",	"a0f01a",	"a0f112",	"a0f2a9",	"a0f346",
                "a0f4fc",	"a0f59e",	"a0f647",	"a0fcd6",	"a1008d",	"a10853",	"a10bba",	"a10e6c",	"a115d4",	"a11759",	"a11799",
                "a117cf",	"a11ce7",	"a1209e",	"a123c7",	"a12455",	"a12473",	"a12f7a",	"a136e8",	"a13a9f",	"a13f4e",	"a14577",
                "a14c8f",	"a14d65",	"a14fc2",	"a1511c",	"a15379",	"a154d3",	"a1588a",	"a15ae7",	"a15e9e",	"a1621e",	"a165f3",
                "a16865",	"a16926",	"a16c1c",	"a16d79",	"a16fd3",	"a1735b",	"a1770a",	"a17741",	"a17e23",	"a1801f",	"a1869e",
                "a189b7",	"a18a1d",	"a18d63",	"a18dd6",	"a18fbc",	"a1906f",	"a190f5",	"a191b5",	"a19700",	"a1993a",	"a19b71",
                "a19d62",	"a19dd8",	"a19e6e",	"a19f99",	"a1a0f3",	"a1a119",	"a1a225",	"a1a4b3",	"a1a4b7",	"a1a4c1",	"a1a4d6",
                "a1a4f8",	"a1a517",	"a1a554",	"a1a588",	"a1a59c",	"a1a5dc",	"a1a5ed",	"a1a60d",	"a1a615",	"a1a62a",	"a1a649",
                "a1a674",	"a1a692",	"a1a69f",	"a1a85b",	"a1a86b",	"a1a883",	"a1a8eb",	"a1a96e",	"a1a993",	"a1a99d",	"a1a9d9",
                "a1a9de",	"a1a9e4",	"a1aab2",	"a1ac3e",	"a1ac44",	"a1affb",	"a1b109",	"a1b3b2",	"a1b4b8",	"a1b4c0",	"a1ba96",
                "a1c0f8",	"a1c11b",	"a1c1ad",	"a1c1d2",	"a1c236",	"a1c2a1",	"a1c2ce",	"a1c44e",	"a1c589",	"a1c63b",	"a1c877",
                "a1c940",	"a1ca0f",	"a1cbf1",	"a1ccb3",	"a1ccf7",	"a1d006",	"a1d06a",	"a1d11a",	"a1d386",	"a1d4d1",	"a1d73d",
                "a1d7d8",	"a1df0d",	"a1dffb",	"a1e55c",	"a1e582",	"a1e91f",	"a1ece7",	"a1ef73",	"a1fac6",	"a1fad1",	"a2032a",
                "a20331",	"a205da",	"a20db9",	"a210a8",	"a2137e",	"a213c0",	"a2177d",	"a218a9",	"a21ec9",	"a22284",	"a222ab",
                "a222bb",	"a22672",	"a229c5",	"a22a29",	"a22f63",	"a233f0",	"a23434",	"a2378e",	"a237a7",	"a23b27",	"a24243",
                "a2424a",	"a242cc",	"a2454e",	"a24683",	"a24a03",	"a24cda",	"a255c3",	"a255ea",	"a267f6",	"a27d69",	"a27dcb",
                "a28220",	"a28729",	"a299e0",	"a2a063",	"a2a4e8",	"a2bc47",	"a2c15f",	"a2c346",	"a2c3df",	"a2c825",	"a2cc5a",
                "a2cc67",	"a2d941",	"a2e1ad",	"a2e4db",	"a2ebed",	"a2f72b",	"a2fd09",	"a3019f",	"a3090d",	"a31894",	"a31fca",
                "a32343",	"a3238a",	"a323c6",	"a32741",	"a32a80",	"a32af8",	"a32bc0",	"a32eaf",	"a32f49",	"a33266",	"a33300",
                "a3361d",	"a3362e",	"a336b7",	"a3372e",	"a33a6e",	"a33ae5",	"a33e25",	"a33e9c",	"a341dc",	"a3448a",	"a34499",
                "a34533",	"a34593",	"a34f21",	"a34f5a",	"a355ac",	"a356c8",	"a3597d",	"a3599e",	"a35afc",	"a35d53",	"a35e1d",
                "a35e36",	"a361d4",	"a363a6",	"a365a3",	"a3670a",	"a36b2b",	"a36bf6",	"a36c09",	"a36cbc",	"a385b5",	"a3896c",
                "a38b85",	"a38b87",	"a38b8d",	"a38d23",	"a3938e",	"a3943b",	"a394c9",	"a39697",	"a3969d",	"a3b588",	"a3b93f",
                "a3bbba",	"a3bf4f",	"a3c306",	"a3c872",	"a3ca74",	"a3d1e2",	"a3e339",	"a3e580",	"a3e5f5",	"a3e5fc",	"a3e65f",
                "a3e677",	"a3e6b8",	"a3e8be",	"a3e916",	"a3ecb3",	"a3edb2",	"a3edcc",	"a3ede5",	"a3ede7",	"a3f056",	"a3f06a",
                "a3f0ca",	"a3f10d",	"a3f18a",	"a3f24a",	"a3f40d",	"a3f4a4",	"a3f541",	"a3fc11",	"a40078",	"a406b4",	"a407e6",
                "a4099b",	"a409b0",	"a40c86",	"a40f42",	"a4106f",	"a42b4a",	"a42dd8",	"a42f42",	"a42f6c",	"a43237",	"a434fa",
                "a4391a",	"a459b6",	"a45a05",	"a46099",	"a46807",	"a46b39",	"a47252",	"a4765e",	"a47a15",	"a47f8d",	"a47fc4",
                "a48030",	"a48135",	"a488f2",	"a48b4a",	"a48b74",	"a48f2b",	"a492b8",	"a4966f",	"a49e07",	"a4a0ed",	"a4a194",
                "a4a4a4",	"a4a9ac",	"a4aa13",	"a4ab0d",	"a4b061",	"a4b116",	"a4b6b1",	"a4b7cb",	"a4bade",	"a4bb24",	"a4bb86",
                "a4bc4d",	"a4bd71",	"a4bf39",	"a4c03c",	"a4c082",	"a4c0ab",	"a4c2fc",	"a4c439",	"a4c6d7",	"a4c6dc",	"a4c6e2",
                "a4c786",	"a4c7a4",	"a4c7b8",	"a4c7bd",	"a4c7c7",	"a4c7e8",	"a4c7f0",	"a4c821",	"a4c824",	"a4c84f",	"a4c858",
                "a4c962",	"a4c964",	"a4c98b",	"a4ca8e",	"a4cb3d",	"a4cba7",	"a4cd6b",	"a4cf5e",	"a4d28c",	"a4d7dd",	"a4d984",
                "a4dc79",	"a4dc89",	"a4dcc8",	"a4dce1",	"a4e2c1",	"a4e2fb",	"a4f2ef",	"a4f436",	"a4fc17",	"a4fd21",	"a50085",
                "a5065f",	"a5099f",	"a50a26",	"a50ddc",	"a5218a",	"a521d9",	"a533ab",	"a54ed2",	"a55a5c",	"a56aad",	"a56d86",
                "a56ee3",	"a57c91",	"a57cfa",	"a58f3c",	"a58fd7",	"a59009",	"a59276",	"a59626",	"a59d87",	"a59f5d",	"a5a13e",
                "a5a314",	"a5a6cb",	"a5aa82",	"a5bdc9",	"a5c50b",	"a5c8c2",	"a5cc79",	"a5d1a7",	"a5e754",	"a5e761",	"a5e9be",
                "a5eca1",	"a5f1b9",	"a60650",	"a606a2",	"a60a59",	"a60ed3",	"a61069",	"a611a9",	"a61420",	"a61b8e",	"a61f45",
                "a622fc",	"a6269c",	"a626b3",	"a62a6a",	"a62cf5",	"a62e21",	"a62f27",	"a631d8",	"a63a5c",	"a63a5e",	"a63b1f",
                "a63c4f",	"a63c75",	"a63d43",	"a63e11",	"a6406f",	"a6420f",	"a6421c",	"a64936",	"a64e8c",	"a65695",	"a662bd",
                "a66378",	"a664e4",	"a66a2b",	"a66a87",	"a66bf3",	"a66f68",	"a66f8c",	"a678b8",	"a68040",	"a6834a",	"a68361",
                "a68694",	"a686ad",	"a695c0",	"a6a060",	"a6a9d9",	"a6abf5",	"a6acee",	"a6b152",	"a6c007",	"a6cd42",	"a6cfd2",
                "a6d5ab",	"a6dc21",	"a6ead0",	"a6fadd",	"a703e0",	"a7067c",	"a724a9",	"a724b2",	"a72aaa",	"a72c34",	"a72dc2",
                "a72e61",	"a742cc",	"a74412",	"a74cf2",	"a74e6e",	"a753b3",	"a75d35",	"a76043",	"a76063",	"a76595",	"a772dd",
                "a772fc",	"a77300",	"a77397",	"a773a7",	"a77447",	"a77780",	"a77c9c",	"a77d4c",	"a783ee",	"a7875d",	"a7880f",
                "a7af01",	"a7afb2",	"a7b31d",	"a7b341",	"a7b68e",	"a7c2b1",	"a7c341",	"a7c509",	"a7c634",	"a7cb98",	"a7cc8f",
                "a7cdb1",	"a7de35",	"a7e75f",	"a7eb20",	"a7eb97",	"a7eba5",	"a7ed0b",	"a7eda6",	"a7edb3",	"a7f0c7",	"a7f2b1",
                "a7f668",	"a7f7d6",	"a7fa1f",	"a7fc9a",	"a7fca7",	"a7fd99",	"a7fdd6",	"a7fe51",	"a8011d",	"a8018d",	"a808c2",
                "a808fb",	"a80c79",	"a80cb2",	"a80ef2",	"a814a1",	"a81532",	"a81b8c",	"a81ef2",	"a822a9",	"a822ab",	"a822ab",
                "a82555",	"a8290c",	"a82c86",	"a82cc3",	"a837ab",	"a83c14",	"a83cb1",	"a84071",	"a846bc",	"a84a73",	"a84a74",
                "a84e2a",	"a84f80",	"a8547b",	"a85598",	"a85f05",	"a863fd",	"a86430",	"a8664f",	"a88baf",	"a89121",	"a893a5",
                "a8a4b8",	"a8aa75",	"a8ab22",	"a8b298",	"a8bc56",	"a8d092",	"a8d122",	"a8d145",	"a8d493",	"a8d5ab",	"a8d657",
                "a8d68b",	"a8daad",	"a8e696",	"a8ec45",	"a8effc",	"a8f3b3",	"a900dd",	"a9022c",	"a912c2",	"a913ab",	"a92555",
                "a929a8",	"a943ae",	"a94778",	"a9485a",	"a94da4",	"a95090",	"a95282",	"a954fa",	"a960ed",	"a96d4f",	"a9738f",
                "a97906",	"a97a6f",	"a97e05",	"a98062",	"a980f9",	"a982dc",	"a9848e",	"a98991",	"a98f61",	"a99318",	"a99a63",
                "a99a86",	"a99adc",	"a99ae0",	"a99e3d",	"a9a08c",	"a9a44d",	"a9abbb",	"a9ac00",	"a9b2a2",	"a9b6e0",	"a9ba97",
                "a9c96a",	"a9fefc",	"aa0632",	"aa4249",	"aa4cb2",	"aa5c38",	"aa743c",	"aa7f72",	"aa849e",	"aa84b5",	"aa8e56",
                "aa8e94",	"aa9307",	"aaac27",	"aab63f",	"aac034",	"aac3eb",	"aacb59",	"aaddc9",	"aaded5",	"aae0b8",	"aae234",
                "aae5d1",	"aaea99",	"aaeafc",	"aaee50",	"aaf207",	"aaf9b9",	"aafcb7",	"aaffb6",	"ab0df5",	"ab11cc",	"ab1d90",
                "ab1eff",	"ab282a",	"ab2ea3",	"ab3076",	"ab3b9f",	"ab4c04",	"ab4f43",	"ab62a2",	"ab6e40",	"ab6fea",	"ab7758",
                "ab7dbc",	"aba64d",	"aba652",	"aba6ab",	"abb067",	"abb6e3",	"abc18d",	"abd532",	"abde62",	"abe5d0",	"abed3e",
                "ac0235",	"ac54df",	"ac54e0",	"ac6aff",	"ac6bc8",	"ac6faf",	"ac6fe3",	"ac7622",	"ac7706",	"ac7811",	"ac7859",
                "ac7a29",	"ac7cc3",	"ac8158",	"ac85b0",	"ac894e",	"ac8967",	"ac95fc",	"ac96d4",	"ac9896",	"ac9aa8",	"ac9af0",
                "ac9b1e",	"ac9b26",	"ac9b51",	"ac9b58",	"ac9c2c",	"ac9c4d",	"ac9c63",	"ac9d8a",	"ac9e06",	"ac9ed4",	"ac9f0f",
                "aca0ac",	"aca0cf",	"aca12c",	"aca352",	"acbd1f",	"acbf00",	"acc626",	"acd550",	"acdb5b",	"acdc20",	"ace3a1",
                "acf108",	"acf876",	"ad2763",	"ad2b1a",	"ad2ed1",	"ad33e8",	"ad3535",	"ad4eab",	"ad5418",	"ad5a34",	"ad72fe",
                "ad80d4",	"ad829a",	"ad8556",	"ad8556",	"ad878a",	"ad8be2",	"ad9330",	"ad97b7",	"ad9de0",	"ada693",	"adaa0c",
                "adaa79",	"adb7c8",	"adc6bb",	"adc8f5",	"adea36",	"adec58",	"adef02",	"adf1f3",	"adf349"]

# %%
from pyopensky import OpenskyImpalaWrapper
from osgeo import ogr
from osgeo import osr
import csv
opensky = OpenskyImpalaWrapper()


for i in range(len(ListHeli2017)):
    print(i)
    i = i+711
    # Perform a query with ICAO filter
    df = opensky.query(
        source="rollcall",
        #start="2017-06-01 13:00:00",
        #end="2017-07-01 13:00:10",
        start="2017-01-01",
        end="2017-12-01",
        icao24=[ListHeli2017[i]],#722 vs 721  a99a63
        type = "adsb"
    )
    
    if df is not None:
        filepathcsvNA = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\CSVfromPythonwNA\\"+ListHeli2017[i]+".csv"
        df.to_csv(filepathcsvNA)

        df2 = df.dropna(subset = ["lat"])          # Apply dropna() function to remove missing lat lon 
        if len(df2) > 0:
            filepathcsv = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\CSVfromPython\\"+ListHeli2017[i]+".csv"
            df2.to_csv(filepathcsv)
        
            filepathshp = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\SHPfromPython\\"+ListHeli2017[i]+".shp"
            driver = ogr.GetDriverByName("ESRI Shapefile")
            data_src = driver.CreateDataSource(filepathshp)
            srs = osr.SpatialReference()
            srs.ImportFromEPSG(4326)# 4326 = wgs84
            layer = data_src.CreateLayer(filepathshp, 
                                         srs, 
                                         geom_type = ogr.wkbPoint)

            #Create attribute fields from OpenSky
            field_name = ogr.FieldDefn("time", ogr.OFTString)
            field_name.SetWidth(50)
            layer.CreateField(field_name)
            layer.CreateField(ogr.FieldDefn("lon", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("lat", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("velocity", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("heading", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("vertrate", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("callsign", ogr.OFTString))
            layer.CreateField(ogr.FieldDefn("onground", ogr.OFTString))
            layer.CreateField(ogr.FieldDefn("alert", ogr.OFTString))
            layer.CreateField(ogr.FieldDefn("spi", ogr.OFTString))
            layer.CreateField(ogr.FieldDefn("squawk", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("baro", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("geo", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("lastpos", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("lastcon", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("hour", ogr.OFTString))
    
            with open(filepathcsv, "r") as csv_file:
                csv_reader = csv.reader(csv_file)
                next(csv_reader)
                for row in csv_reader:        
                    feature = ogr.Feature(layer.GetLayerDefn())
                    feature.SetField("time", row[1])
                    feature.SetField("lon", row[4])
                    feature.SetField("lat", row[3])
                    feature.SetField("velocity", row[5])
                    feature.SetField("heading", row[6])
                    feature.SetField("vertrate", row[7])
                    feature.SetField("callsign", row[8])
                    feature.SetField("onground", row[9])
                    feature.SetField("alert", row[10])
                    feature.SetField("spi", row[11])
                    feature.SetField("squawk", row[12])
                    feature.SetField("baro", row[13])
                    feature.SetField("geo", row[14])
                    feature.SetField("lastpos", row[15])
                    feature.SetField("lastcon", row[16])
                    feature.SetField("hour", row[17])
     
                    #Create point geometry
                    point = ogr.Geometry(ogr.wkbPoint)
                    point.AddPoint(float(row[4]), float(row[3]))

 "aaffb6",
 "ab0181",
 "ab0818",
 "ab0a57",
 "ab0df5",
 "ab11cc",
 "ab1d90",
 "ab1eff",
 "ab2ea3",
 "ab3076",
 "ab358d",
 "ab4f43",
 "ab51bd",
 "ab62a2",
 "ab6e40",
 "ab6fea",
 "ab6fea",
 "ab7758",
 "ab7dbc",
 "ab7f14",
 "ab928d",
 "aba64d",
 "aba652",
 "abb067",
 "abb6e3",
 "abc18d",
 "abd532",
 "abde62",
 "abe5d0",
 "abed3e",
 "ac0235",
 "ac1d26",
 "ac54df",
 "ac54e0",
 "ac6aff",
 "ac6bc8",
 "ac6faf",
 "ac6fe3",
 "ac7706",
 "ac7859",
 "ac7cc3",
 "ac7e0e",
 "ac8158",
 "ac81f9",
 "ac85b0",
 "ac894e",
 "ac8967",
 "ac8b19",
 "ac95fc",
 "ac95fc",
 "ac96d4",
 "ac96d4",
 "ac9a7a",
 "ac9aa8",
 "ac9af0",
 "ac9b1e",
 "ac9b26",
 "ac9b51",
 "ac9b57",
 "ac9b58",
 "ac9b85",
 "ac9c0a",
 "ac9c2c",
 "ac9c4d",
 "ac9cb9",
 "ac9d8a",
 "ac9ed4",
 "aca0cf",
 "aca12c",
 "aca352",
 "acbd1f",
 "acbf00",
 "acc626",
 "acdb5b",
 "acdc20",
 "acf108",
 "ad1497",
 "ad2763",
 "ad2b1a",
 "ad2ed1",
 "ad33e8",
 "ad3400",
 "ad34e1",
 "ad3535",
 "ad4eab",
 "ad5418",
 "ad5a34",
 "ad6c94",
 "ad72fe",
 "ad80d4",
 "ad829a",
 "ad829d",
 "ad8556",
 "ad8556",
 "ad878a",
 "ad8be2",
 "ad9330",
 "ad97b7",
 "ad9de0",
 "ada693",
 "adaa0c",
 "adaa79",
 "adb7c8",
 "adc6bb",
 "adc8f5",
 "add43e",
 "add55b",
 "adea36",
 "adec58",
 "adec59",
 "adef02",
 "adf1f3",
 "adf212",
 "adf349"]

# %%
data["BOUND"]= [data.Latitude1PLUS,data.Latitude1MINUS,data.Longitude1PLUS,data.Longitude1MINUS]

# %%
data.Latitude1PLUS

# %%
from pyopensky import OpenskyImpalaWrapper
from osgeo import ogr
from osgeo import osr
import csv
opensky = OpenskyImpalaWrapper()
i=600
df = opensky.query(
        source="rollcall",
        #start="2017-06-01 13:00:00",
        #end="2017-06-10 13:20:10",
        #start="2017-07-01",
        #end="2017-07-02",
        start = data.Time1[i],
        end = data.Time2[i],
        bound=[data.Longitude1MINUS[i],data.Longitude1PLUS[i],data.Latitude1MINUS[i],data.Latitude1PLUS[i]],
        #bound=[-117.835006713867,-117.835006713868,33.6692962646484,33.6692962646485],
        icao24=["a003d8",	"a00996",	"a00d9f",	"a00df0",	"a011d0",	"a01663",	"a01717",	"a01b0a",	"a01bc9",	"a01d3d",	"a01ee6",
                "a01eef",	"a020f4",	"a0218b",	"a021e6",	"a02232",	"a02234",	"a02460",	"a02504",	"a02585",	"a025e9",	"a02737",
                "a02862",	"a028ac",	"a028af",	"a02ac9",	"a02cb3",	"a02eff",	"a02f59",	"a02f8e",	"a02fbe",	"a03045",	"a030f1",
                "a037d9",	"a03b8f",	"a03b90",	"a03ec5",	"a0427c",	"a0441d",	"a04600",	"a04640",	"a0468f",	"a047d2",	"a047d4",
                "a04b00",	"a04b89",	"a04f40",	"a05158",	"a05213",	"a0521e",	"a054ad",	"a0554a",	"a056e3",	"a05a76",	"a05b11",
                "a05b4b",	"a05ba0",	"a06299",	"a0630e",	"a0633d",	"a06682",	"a06aa7",	"a071ea",	"a07655",	"a078ea",	"a0795d",
                "a080a9",	"a082af",	"a082c0",	"a08852",	"a08de5",	"a08e0f",	"a0919c",	"a09451",	"a09501",	"a09553",	"a0a10e",
                "a0a11c",	"a0a152",	"a0a328",	"a0a6e5",	"a0a818",	"a0aa23",	"a0ab32",	"a0af73",	"a0af86",	"a0b0ea",	"a0b1ad",
                "a0b2a0",	"a0b657",	"a0b6f4",	"a0baab",	"a0be62",	"a0c219",	"a0c5d0",	"a0c89b",	"a0c8d1",	"a0cae6",	"a0cafb",
                "a0d19c",	"a0d90e",	"a0dabf",	"a0e77d",	"a0e7ea",	"a0eba1",	"a0f005",	"a0f01a",	"a0f112",	"a0f2a9",	"a0f346",
                "a0f4fc",	"a0f59e",	"a0f647",	"a0fcd6",	"a1008d",	"a10853",	"a10bba",	"a10e6c",	"a115d4",	"a11759",	"a11799",
                "a117cf",	"a11ce7",	"a1209e",	"a123c7",	"a12455",	"a12473",	"a12f7a",	"a136e8",	"a13a9f",	"a13f4e",	"a14577",
                "a14c8f",	"a14d65",	"a14fc2",	"a1511c",	"a15379",	"a154d3",	"a1588a",	"a15ae7",	"a15e9e",	"a1621e",	"a165f3",
                "a16865",	"a16926",	"a16c1c",	"a16d79",	"a16fd3",	"a1735b",	"a1770a",	"a17741",	"a17e23",	"a1801f",	"a1869e",
                "a189b7",	"a18a1d",	"a18d63",	"a18dd6",	"a18fbc",	"a1906f",	"a190f5",	"a191b5",	"a19700",	"a1993a",	"a19b71",
                "a19d62",	"a19dd8",	"a19e6e",	"a19f99",	"a1a0f3",	"a1a119",	"a1a225",	"a1a4b3",	"a1a4b7",	"a1a4c1",	"a1a4d6",
                "a1a4f8",	"a1a517",	"a1a554",	"a1a588",	"a1a59c",	"a1a5dc",	"a1a5ed",	"a1a60d",	"a1a615",	"a1a62a",	"a1a649",
                "a1a674",	"a1a692",	"a1a69f",	"a1a85b",	"a1a86b",	"a1a883",	"a1a8eb",	"a1a96e",	"a1a993",	"a1a99d",	"a1a9d9",
                "a1a9de",	"a1a9e4",	"a1aab2",	"a1ac3e",	"a1ac44",	"a1affb",	"a1b109",	"a1b3b2",	"a1b4b8",	"a1b4c0",	"a1ba96",
                "a1c0f8",	"a1c11b",	"a1c1ad",	"a1c1d2",	"a1c236",	"a1c2a1",	"a1c2ce",	"a1c44e",	"a1c589",	"a1c63b",	"a1c877",
                "a1c940",	"a1ca0f",	"a1cbf1",	"a1ccb3",	"a1ccf7",	"a1d006",	"a1d06a",	"a1d11a",	"a1d386",	"a1d4d1",	"a1d73d",
                "a1d7d8",	"a1df0d",	"a1dffb",	"a1e55c",	"a1e582",	"a1e91f",	"a1ece7",	"a1ef73",	"a1fac6",	"a1fad1",	"a2032a",
                "a20331",	"a205da",	"a20db9",	"a210a8",	"a2137e",	"a213c0",	"a2177d",	"a218a9",	"a21ec9",	"a22284",	"a222ab",
                "a222bb",	"a22672",	"a229c5",	"a22a29",	"a22f63",	"a233f0",	"a23434",	"a2378e",	"a237a7",	"a23b27",	"a24243",
                "a2424a",	"a242cc",	"a2454e",	"a24683",	"a24a03",	"a24cda",	"a255c3",	"a255ea",	"a267f6",	"a27d69",	"a27dcb",
                "a28220",	"a28729",	"a299e0",	"a2a063",	"a2a4e8",	"a2bc47",	"a2c15f",	"a2c346",	"a2c3df",	"a2c825",	"a2cc5a",
                "a2cc67",	"a2d941",	"a2e1ad",	"a2e4db",	"a2ebed",	"a2f72b",	"a2fd09",	"a3019f",	"a3090d",	"a31894",	"a31fca",
                "a32343",	"a3238a",	"a323c6",	"a32741",	"a32a80",	"a32af8",	"a32bc0",	"a32eaf",	"a32f49",	"a33266",	"a33300",
                "a3361d",	"a3362e",	"a336b7",	"a3372e",	"a33a6e",	"a33ae5",	"a33e25",	"a33e9c",	"a341dc",	"a3448a",	"a34499",
                "a34533",	"a34593",	"a34f21",	"a34f5a",	"a355ac",	"a356c8",	"a3597d",	"a3599e",	"a35afc",	"a35d53",	"a35e1d",
                "a35e36",	"a361d4",	"a363a6",	"a365a3",	"a3670a",	"a36b2b",	"a36bf6",	"a36c09",	"a36cbc",	"a385b5",	"a3896c",
                "a38b85",	"a38b87",	"a38b8d",	"a38d23",	"a3938e",	"a3943b",	"a394c9",	"a39697",	"a3969d",	"a3b588",	"a3b93f",
                "a3bbba",	"a3bf4f",	"a3c306",	"a3c872",	"a3ca74",	"a3d1e2",	"a3e339",	"a3e580",	"a3e5f5",	"a3e5fc",	"a3e65f",
                "a3e677",	"a3e6b8",	"a3e8be",	"a3e916",	"a3ecb3",	"a3edb2",	"a3edcc",	"a3ede5",	"a3ede7",	"a3f056",	"a3f06a",
                "a3f0ca",	"a3f10d",	"a3f18a",	"a3f24a",	"a3f40d",	"a3f4a4",	"a3f541",	"a3fc11",	"a40078",	"a406b4",	"a407e6",
                "a4099b",	"a409b0",	"a40c86",	"a40f42",	"a4106f",	"a42b4a",	"a42dd8",	"a42f42",	"a42f6c",	"a43237",	"a434fa",
                "a4391a",	"a459b6",	"a45a05",	"a46099",	"a46807",	"a46b39",	"a47252",	"a4765e",	"a47a15",	"a47f8d",	"a47fc4",
                "a48030",	"a48135",	"a488f2",	"a48b4a",	"a48b74",	"a48f2b",	"a492b8",	"a4966f",	"a49e07",	"a4a0ed",	"a4a194",
                "a4a4a4",	"a4a9ac",	"a4aa13",	"a4ab0d",	"a4b061",	"a4b116",	"a4b6b1",	"a4b7cb",	"a4bade",	"a4bb24",	"a4bb86",
                "a4bc4d",	"a4bd71",	"a4bf39",	"a4c03c",	"a4c082",	"a4c0ab",	"a4c2fc",	"a4c439",	"a4c6d7",	"a4c6dc",	"a4c6e2",
                "a4c786",	"a4c7a4",	"a4c7b8",	"a4c7bd",	"a4c7c7",	"a4c7e8",	"a4c7f0",	"a4c821",	"a4c824",	"a4c84f",	"a4c858",
                "a4c962",	"a4c964",	"a4c98b",	"a4ca8e",	"a4cb3d",	"a4cba7",	"a4cd6b",	"a4cf5e",	"a4d28c",	"a4d7dd",	"a4d984",
                "a4dc79",	"a4dc89",	"a4dcc8",	"a4dce1",	"a4e2c1",	"a4e2fb",	"a4f2ef",	"a4f436",	"a4fc17",	"a4fd21",	"a50085",
                "a5065f",	"a5099f",	"a50a26",	"a50ddc",	"a5218a",	"a521d9",	"a533ab",	"a54ed2",	"a55a5c",	"a56aad",	"a56d86",
                "a56ee3",	"a57c91",	"a57cfa",	"a58f3c",	"a58fd7",	"a59009",	"a59276",	"a59626",	"a59d87",	"a59f5d",	"a5a13e",
                "a5a314",	"a5a6cb",	"a5aa82",	"a5bdc9",	"a5c50b",	"a5c8c2",	"a5cc79",	"a5d1a7",	"a5e754",	"a5e761",	"a5e9be",
                "a5eca1",	"a5f1b9",	"a60650",	"a606a2",	"a60a59",	"a60ed3",	"a61069",	"a611a9",	"a61420",	"a61b8e",	"a61f45",
                "a622fc",	"a6269c",	"a626b3",	"a62a6a",	"a62cf5",	"a62e21",	"a62f27",	"a631d8",	"a63a5c",	"a63a5e",	"a63b1f",
                "a63c4f",	"a63c75",	"a63d43",	"a63e11",	"a6406f",	"a6420f",	"a6421c",	"a64936",	"a64e8c",	"a65695",	"a662bd",
                "a66378",	"a664e4",	"a66a2b",	"a66a87",	"a66bf3",	"a66f68",	"a66f8c",	"a678b8",	"a68040",	"a6834a",	"a68361",
                "a68694",	"a686ad",	"a695c0",	"a6a060",	"a6a9d9",	"a6abf5",	"a6acee",	"a6b152",	"a6c007",	"a6cd42",	"a6cfd2",
                "a6d5ab",	"a6dc21",	"a6ead0",	"a6fadd",	"a703e0",	"a7067c",	"a724a9",	"a724b2",	"a72aaa",	"a72c34",	"a72dc2",
                "a72e61",	"a742cc",	"a74412",	"a74cf2",	"a74e6e",	"a753b3",	"a75d35",	"a76043",	"a76063",	"a76595",	"a772dd",
                "a772fc",	"a77300",	"a77397",	"a773a7",	"a77447",	"a77780",	"a77c9c",	"a77d4c",	"a783ee",	"a7875d",	"a7880f",
                "a7af01",	"a7afb2",	"a7b31d",	"a7b341",	"a7b68e",	"a7c2b1",	"a7c341",	"a7c509",	"a7c634",	"a7cb98",	"a7cc8f",
                "a7cdb1",	"a7de35",	"a7e75f",	"a7eb20",	"a7eb97",	"a7eba5",	"a7ed0b",	"a7eda6",	"a7edb3",	"a7f0c7",	"a7f2b1",
                "a7f668",	"a7f7d6",	"a7fa1f",	"a7fc9a",	"a7fca7",	"a7fd99",	"a7fdd6",	"a7fe51",	"a8011d",	"a8018d",	"a808c2",
                "a808fb",	"a80c79",	"a80cb2",	"a80ef2",	"a814a1",	"a81532",	"a81b8c",	"a81ef2",	"a822a9",	"a822ab",	"a822ab",
                "a82555",	"a8290c",	"a82c86",	"a82cc3",	"a837ab",	"a83c14",	"a83cb1",	"a84071",	"a846bc",	"a84a73",	"a84a74",
                "a84e2a",	"a84f80",	"a8547b",	"a85598",	"a85f05",	"a863fd",	"a86430",	"a8664f",	"a88baf",	"a89121",	"a893a5",
                "a8a4b8",	"a8aa75",	"a8ab22",	"a8b298",	"a8bc56",	"a8d092",	"a8d122",	"a8d145",	"a8d493",	"a8d5ab",	"a8d657",
                "a8d68b",	"a8daad",	"a8e696",	"a8ec45",	"a8effc",	"a8f3b3",	"a900dd",	"a9022c",	"a912c2",	"a913ab",	"a92555",
                "a929a8",	"a943ae",	"a94778",	"a9485a",	"a94da4",	"a95090",	"a95282",	"a954fa",	"a960ed",	"a96d4f",	"a9738f",
                "a97906",	"a97a6f",	"a97e05",	"a98062",	"a980f9",	"a982dc",	"a9848e",	"a98991",	"a98f61",	"a99318",	"a99a63",
                "a99a86",	"a99adc",	"a99ae0",	"a99e3d",	"a9a08c",	"a9a44d",	"a9abbb",	"a9ac00",	"a9b2a2",	"a9b6e0",	"a9ba97",
                "a9c96a",	"a9fefc",	"aa0632",	"aa4249",	"aa4cb2",	"aa5c38",	"aa743c",	"aa7f72",	"aa849e",	"aa84b5",	"aa8e56",
                "aa8e94",	"aa9307",	"aaac27",	"aab63f",	"aac034",	"aac3eb",	"aacb59",	"aaddc9",	"aaded5",	"aae0b8",	"aae234",
                "aae5d1",	"aaea99",	"aaeafc",	"aaee50",	"aaf207",	"aaf9b9",	"aafcb7",	"aaffb6",	"ab0df5",	"ab11cc",	"ab1d90",
                "ab1eff",	"ab282a",	"ab2ea3",	"ab3076",	"ab3b9f",	"ab4c04",	"ab4f43",	"ab62a2",	"ab6e40",	"ab6fea",	"ab7758",
                "ab7dbc",	"aba64d",	"aba652",	"aba6ab",	"abb067",	"abb6e3",	"abc18d",	"abd532",	"abde62",	"abe5d0",	"abed3e",
                "ac0235",	"ac54df",	"ac54e0",	"ac6aff",	"ac6bc8",	"ac6faf",	"ac6fe3",	"ac7622",	"ac7706",	"ac7811",	"ac7859",
                "ac7a29",	"ac7cc3",	"ac8158",	"ac85b0",	"ac894e",	"ac8967",	"ac95fc",	"ac96d4",	"ac9896",	"ac9aa8",	"ac9af0",
                "ac9b1e",	"ac9b26",	"ac9b51",	"ac9b58",	"ac9c2c",	"ac9c4d",	"ac9c63",	"ac9d8a",	"ac9e06",	"ac9ed4",	"ac9f0f",
                "aca0ac",	"aca0cf",	"aca12c",	"aca352",	"acbd1f",	"acbf00",	"acc626",	"acd550",	"acdb5b",	"acdc20",	"ace3a1",
                "acf108",	"acf876",	"ad2763",	"ad2b1a",	"ad2ed1",	"ad33e8",	"ad3535",	"ad4eab",	"ad5418",	"ad5a34",	"ad72fe",
                "ad80d4",	"ad829a",	"ad8556",	"ad8556",	"ad878a",	"ad8be2",	"ad9330",	"ad97b7",	"ad9de0",	"ada693",	"adaa0c",
                "adaa79",	"adb7c8",	"adc6bb",	"adc8f5",	"adea36",	"adec58",	"adef02",	"adf1f3",	"adf349"],#722 vs 721  a99a63
        type = "adsb"
    )

# %%
df

# %%
import numpy
numpy.unique(df["icao24"])

# %%
df2 = df.dropna(subset = ["lat"])          # Apply dropna() function
df2.to_csv("C:\\Users\\admin-magstadt\\Desktop\\ADSBScratch\\testcsv_1_18_2022.csv")

# %%
from osgeo import ogr
from osgeo import osr
import csv

pathtocreateSHAPEFILE = "C:\\Users\\admin-magstadt\\Desktop\\ADSBScratch\\test07_1_2022.shp"
#pathtoCSVwLATLON = "C:\\Users\\admin-magstadt\\Desktop\\ADSBScratch\\testcsv.csv"
pathtoCSVwLATLON = "C:\\Users\\admin-magstadt\\Desktop\\ADSBScratch\\testcsv_7_1_2022.csv"

driver = ogr.GetDriverByName("ESRI Shapefile")
data_src = driver.CreateDataSource(pathtocreateSHAPEFILE)
srs = osr.SpatialReference()
srs.ImportFromEPSG(4326)# 4326 = wgs84
layer = data_src.CreateLayer(pathtocreateSHAPEFILE, 
                             srs, 
                             geom_type = ogr.wkbPoint)

#Create attribute fields from OpenSky
field_name = ogr.FieldDefn("time", ogr.OFTString)
field_name.SetWidth(50)
layer.CreateField(field_name)
layer.CreateField(ogr.FieldDefn("lon", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("lat", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("velocity", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("heading", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("vertrate", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("callsign", ogr.OFTString))
layer.CreateField(ogr.FieldDefn("onground", ogr.OFTString))
layer.CreateField(ogr.FieldDefn("alert", ogr.OFTString))
layer.CreateField(ogr.FieldDefn("spi", ogr.OFTString))
layer.CreateField(ogr.FieldDefn("squawk", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("baro", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("geo", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("lastpos", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("lastcon", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("hour", ogr.OFTString))

with open(pathtoCSVwLATLON, "r") as csv_file:
    csv_reader = csv.reader(csv_file)
    next(csv_reader)
    for row in csv_reader:        
        feature = ogr.Feature(layer.GetLayerDefn())
        feature.SetField("time", row[1])
        feature.SetField("lon", row[4])
        feature.SetField("lat", row[3])
        feature.SetField("velocity", row[5])
        feature.SetField("heading", row[6])
        feature.SetField("vertrate", row[7])
        feature.SetField("callsign", row[8])
        feature.SetField("onground", row[9])
        feature.SetField("alert", row[10])
        feature.SetField("spi", row[11])
        feature.SetField("squawk", row[12])
        feature.SetField("baro", row[13])
        feature.SetField("geo", row[14])
        feature.SetField("lastpos", row[15])
        feature.SetField("lastcon", row[16])
        feature.SetField("hour", row[17])
     
        #Create point geometry
        point = ogr.Geometry(ogr.wkbPoint)
        point.AddPoint(float(row[4]), float(row[3]))

        #Create the feature and set the values 
        feature.SetGeometry(point)
        layer.CreateFeature(feature)
        # reset features for next row
        feature = None
data_src = None

# %%
data["BOUND"]= [data.Latitude1PLUS,data.Latitude1MINUS,data.Longitude1PLUS,data.Longitude1MINUS]

# %%
filepathshp = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\SHPfromPython\\"+ListHeli2017[i]+".shp"
type(filepathshp)

# %%
filepathcsv = ["C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\CSVfromPython\\"+ListHeli2017[1]+".csv"]
texts

# %%
# Perform a query with ICAO filter
df = opensky.query(
    source="rollcall",
    #start="2017-06-01 13:00:00",
    #end="2017-07-01 13:00:10",
    #start="2017-06-01 13:00",
    #end="2017-07-01 13:00",
    start="2017-01-01",
    end="2017-12-01",
    icao24=["a99a63"],#722 vs 721  a99a63
    type = "adsb"
)

# %%
df2 = df.dropna(subset = ["lat"])          # Apply dropna() function
df2

# %%
from osgeo import ogr
from osgeo import osr
import csv

pathtocreateSHAPEFILE = "C:\\Users\\admin-magstadt\\Desktop\\ADSBScratch\\test12_1_202211.shp"
pathtoCSVwLATLON = "C:\\Users\\admin-magstadt\\Desktop\\ADSBScratch\\testcsv.csv"

driver = ogr.GetDriverByName("ESRI Shapefile")
data_src = driver.CreateDataSource(pathtocreateSHAPEFILE)
srs = osr.SpatialReference()
srs.ImportFromEPSG(4326)# 4326 = wgs84
layer = data_src.CreateLayer(pathtocreateSHAPEFILE, 
                             srs, 
                             geom_type = ogr.wkbPoint)

#Create attribute fields from OpenSky
field_name = ogr.FieldDefn("time", ogr.OFTString)
field_name.SetWidth(50)
layer.CreateField(field_name)
layer.CreateField(ogr.FieldDefn("lon", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("lat", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("velocity", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("heading", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("vertrate", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("callsign", ogr.OFTString))
layer.CreateField(ogr.FieldDefn("onground", ogr.OFTString))
layer.CreateField(ogr.FieldDefn("alert", ogr.OFTString))
layer.CreateField(ogr.FieldDefn("spi", ogr.OFTString))
layer.CreateField(ogr.FieldDefn("squawk", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("baro", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("geo", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("lastpos", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("lastcon", ogr.OFTReal))
layer.CreateField(ogr.FieldDefn("hour", ogr.OFTString))

with open(pathtoCSVwLATLON, "r") as csv_file:
    csv_reader = csv.reader(csv_file)
    next(csv_reader)
    for row in csv_reader:        
        feature = ogr.Feature(layer.GetLayerDefn())
        feature.SetField("time", row[1])
        feature.SetField("lon", row[4])
        feature.SetField("lat", row[3])
        feature.SetField("velocity", row[5])
        feature.SetField("heading", row[6])
        feature.SetField("vertrate", row[7])
        feature.SetField("callsign", row[8])
        feature.SetField("onground", row[9])
        feature.SetField("alert", row[10])
        feature.SetField("spi", row[11])
        feature.SetField("squawk", row[12])
        feature.SetField("baro", row[13])
        feature.SetField("geo", row[14])
        feature.SetField("lastpos", row[15])
        feature.SetField("lastcon", row[16])
        feature.SetField("hour", row[17])
     
        #Create point geometry
        point = ogr.Geometry(ogr.wkbPoint)
        point.AddPoint(float(row[4]), float(row[3]))

        #Create the feature and set the values 
        feature.SetGeometry(point)
        layer.CreateFeature(feature)
        # reset features for next row
        feature = None
data_src = None

# %% [markdown]
# ### CLEAN RUN THROUGH

# %%
from datetime import datetime
from datetime import datetime, timedelta
import pandas as pd

#data = pd.read_csv("C:\\Users\\admin-magstadt\\Desktop\\ADSBScratch\\ATU_2017_TABLE.txt", sep=",", header=0)
#data = pd.read_csv("C:\\Users\\admin-magstadt\\Desktop\\ADSBScratch\\ATU_2021_TABLE.txt", sep=",", header=0)
#data = pd.read_csv("C:\\Users\\admin-magstadt\\Desktop\\ADSBScratch\\ATU_2019_TABLE.txt", sep=",", header=0)
data = pd.read_csv("C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\ATU_2017_2021_ALL_WGS.txt", sep=",", header=0)
#list(data.columns)

data.UTCdateTime1 = data.UTCdateTime1.str.strip(' UTC')
data['UTCdateTime1']= pd.to_datetime(data['UTCdateTime1'])
#data.UTCdateTime2 = datetime.data.UTCdateTime1

time_change = timedelta(minutes=0.25)
data["Time2"] = data.UTCdateTime1 + time_change
data["Time1"] = data.UTCdateTime1 - time_change



data["Latitude1PLUS"] = data.Latitude1+0.1
data["Latitude1MINUS"] = data.Latitude1-0.1

data["Longitude1PLUS"] = data.Longitude1+0.1
data["Longitude1MINUS"] = data.Longitude1-0.1
data.head()

# %% [markdown]
# # 2

# %%
from datetime import datetime
from datetime import datetime, timedelta
import pandas as pd
data = pd.read_csv("C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\ATU_2017_2021_ALL_WGS.txt", sep=",", header=0)
#data = pd.read_csv("C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\ATUData\\ATU_2017_2021_ALL_WGS_500AGL.txt", sep=",", header=0)

#"C:\Users\magst\Desktop\NorCalATUpts\ATU_2017_2021_ALL_WGS_500AGL.txt"

#list(data.columns)

data.UTCdateTim = data.UTCdateTim.str[:-4]
#data['UTCdateTim'] = df['UTCdateTim'].str.slice(stop=-9)

# this is nice
prefixes = ['N130CG', 'N131CG', 'N132CG', 'N137CG', 'N293EA', 'N292EA', 'N294EA', 'N295EA', 'N297EA','N291EA','N138CG']
data = data[data['Drop_ID1'].str.startswith(tuple(prefixes))]

#data = data[data['Drop_ID1'].str.startswith('N130CG')]
#data = data[data['Drop_ID1'].str.startswith('N130CG')]
#data = data[data['Drop_ID1'].str.startswith('N130CG')]

#print(data.UTCdateTim)
data['UTCdateTim']= pd.to_datetime(data['UTCdateTim'])
#data.UTCdateTime2 = datetime.data.UTCdateTim

#time_change = timedelta(minutes=0.25)
#data["Time2"] = data.UTCdateTim + time_change
#data["Time1"] = data.UTCdateTim - time_change

#time_change2 = timedelta(minutes=2.5)
#data["Time2_2"] = data.UTCdateTim + time_change2
#data["Time1_2"] = data.UTCdateTim - time_change2

time_change = timedelta(minutes=0.25)
data["Time2"] = data.UTCdateTim - time_change
data["Time1"] = data.UTCdateTim - time_change*3

time_change2 = timedelta(minutes=2.5)
data["Time2_2"] = data.UTCdateTim - time_change
data["Time1_2"] = data.UTCdateTim - time_change*3

data["Latitude1PLUS"] = data.Latitude1+0.02
data["Latitude1MINUS"] = data.Latitude1-0.02

data["Longitude1PLUS"] = data.Longitude1+0.02
data["Longitude1MINUS"] = data.Longitude1-0.02

dataLatitude1PLUS =data["Latitude1PLUS"].tolist()
dataLatitude1MINUS =data["Latitude1MINUS"].tolist()

dataLongitude1PLUS =data["Longitude1PLUS"].tolist()
dataLongitude1MINUS =data["Longitude1MINUS"].tolist()

dataLongitude1 =  data.Longitude1.tolist()
dataLatitude1 = data.Latitude1.tolist()

#data.head()
#print(data.columns)
datetime1 = data.Time1.tolist()
datetime2 = data.Time2.tolist()

datetime1_2 = data.Time1_2.tolist()
datetime2_2 = data.Time2_2.tolist()

import pandas as pd
import numpy as np
data=data.replace(regex=[':'], value='_')
data=data.replace(regex=['-'], value='_')
data=data.replace(regex=[' '], value='')

#data
data_DropID = data.Drop_ID1.tolist()
#data_DropID


data["AltMeter1"] = data["AltFeet1"]*0.3048
data_ALT = data["AltMeter1"]+200
data_ALT = data_ALT.tolist()
len(data)
# Out:
# 2705

# %%
from pyopensky import OpenskyImpalaWrapper
from osgeo import ogr
from osgeo import osr
import csv

opensky = OpenskyImpalaWrapper()

for i in range(len(data_DropID)):
    print(i)

    # Perform a query with ICAO filter
    df = opensky.query(
        type="adsb",
        #start="2017-06-01 13:00:00",
        #end="2017-07-01 13:00:10",
        #start="2022-06-01",
        #end="2022-08-01",
        start = datetime1[i],
        end = datetime2[i],
        #[lat1, lon1, lat2, lon2]
        #bound=[data.Longitude1MINUS[i],data.Longitude1PLUS[i],data.Latitude1MINUS[i],data.Latitude1PLUS[i]],
        bound=[dataLatitude1MINUS[i],dataLongitude1MINUS[i],dataLatitude1PLUS[i],dataLongitude1PLUS[i]],
        #icao24 = ["a07b6a","a09922","a07f21","a082d8","a0956b","a30104","a2fd4d","a2f996","a304bb","a30872","a30fe0"]
    )
    
    if df is not None:
        #df = df[df["geoaltitude"]<data_ALT[i]]
        
        #df = df[df['lastposupdate'].nunique() > (len(df)-5)]
        #if (df['lastposupdate'].nunique() > (len(df)-8)) is True and (len(df) >25) is True:# and (df['icao24'].nunique() == 1) is True
        if (df['lastposupdate'].nunique() > (len(df)-8)) is True and (len(df) == 31) is True:# and (df['icao24'].nunique() == 1) is True
            
            icaocode24 = df['icao24']
            print("itUniqueEnough")
            df2 = df.dropna(subset = ["lat"])          # Apply dropna() function to remove missing lat lon 
            if len(df2) > 0:
                filepathcsv = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\CSVfromPython\\predrop1\\"+data_DropID[i]+".csv"
                df2.to_csv(filepathcsv)
                filepathshp = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\SHPfromPython\\predrop1\\"+data_DropID[i]+".shp"
                driver = ogr.GetDriverByName("ESRI Shapefile")
                data_src = driver.CreateDataSource(filepathshp)
                srs = osr.SpatialReference()
                srs.ImportFromEPSG(4326)# 4326 = wgs84
                layer = data_src.CreateLayer(filepathshp, 
                                             srs, 
                                             geom_type = ogr.wkbPoint)

                #Create attribute fields from OpenSky
                field_name = ogr.FieldDefn("time", ogr.OFTString)
                field_name.SetWidth(50)
                layer.CreateField(field_name)
                layer.CreateField(ogr.FieldDefn("lon", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lat", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("velocity", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("heading", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("vertrate", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("callsign", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("onground", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("alert", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("spi", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("squawk", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("baro", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("geo", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lastpos", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lastcon", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("hour", ogr.OFTString))
    
                with open(filepathcsv, "r") as csv_file:
                    csv_reader = csv.reader(csv_file)
                    next(csv_reader)
                    for row in csv_reader:        
                        feature = ogr.Feature(layer.GetLayerDefn())
                        feature.SetField("time", row[1])
                        feature.SetField("lon", row[4])
                        feature.SetField("lat", row[3])
                        feature.SetField("velocity", row[5])
                        feature.SetField("heading", row[6])
                        feature.SetField("vertrate", row[7])
                        feature.SetField("callsign", row[8])
                        feature.SetField("onground", row[9])
                        feature.SetField("alert", row[10])
                        feature.SetField("spi", row[11])
                        feature.SetField("squawk", row[12])
                        feature.SetField("baro", row[13])
                        feature.SetField("geo", row[14])
                        feature.SetField("lastpos", row[15])
                        feature.SetField("lastcon", row[16])
                        feature.SetField("hour", row[17])

                        #Create point geometry
                        point = ogr.Geometry(ogr.wkbPoint)
                        point.AddPoint(float(row[4]), float(row[3]))

                        #Create the feature and set the values 
                        feature.SetGeometry(point)
                        layer.CreateFeature(feature)
                        # reset features for next row
                        feature = None
                data_src = None
            
            ##
            dfLong = opensky.query(
                type="adsb",
                #start="2017-06-01 13:00:00",
                #end="2017-07-01 13:00:10",
                #start="2022-06-01",
                #end="2022-08-01",
                start = datetime1_2[i],
                end = datetime2_2[i],
                #[lat1, lon1, lat2, lon2]
                #bound=[data.Longitude1MINUS[i],data.Longitude1PLUS[i],data.Latitude1MINUS[i],data.Latitude1PLUS[i]],
                bound=[dataLatitude1MINUS[i],dataLongitude1MINUS[i],dataLatitude1PLUS[i],dataLongitude1PLUS[i]],
                iaoc24 = icaocode24
                )
            
            df2_long = dfLong.dropna(subset = ["lat"])          # Apply dropna() function to remove missing lat lon 
            if len(df2_long) > 0:
                filepathcsv = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\CSVfromPython\\predrop2\\"+data_DropID[i]+".csv"
                df2_long.to_csv(filepathcsv)
                filepathshp = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\SHPfromPython\\predrop2\\"+data_DropID[i]+".shp"
                driver = ogr.GetDriverByName("ESRI Shapefile")
                data_src = driver.CreateDataSource(filepathshp)
                srs = osr.SpatialReference()
                srs.ImportFromEPSG(4326)# 4326 = wgs84
                layer = data_src.CreateLayer(filepathshp, 
                                             srs, 
                                             geom_type = ogr.wkbPoint)

                #Create attribute fields from OpenSky
                field_name = ogr.FieldDefn("time", ogr.OFTString)
                field_name.SetWidth(50)
                layer.CreateField(field_name)
                layer.CreateField(ogr.FieldDefn("lon", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lat", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("velocity", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("heading", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("vertrate", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("callsign", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("onground", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("alert", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("spi", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("squawk", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("baro", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("geo", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lastpos", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lastcon", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("hour", ogr.OFTString))
    
                with open(filepathcsv, "r") as csv_file:
                    csv_reader = csv.reader(csv_file)
                    next(csv_reader)
                    for row in csv_reader:        
                        feature = ogr.Feature(layer.GetLayerDefn())
                        feature.SetField("time", row[1])
                        feature.SetField("lon", row[4])
                        feature.SetField("lat", row[3])
                        feature.SetField("velocity", row[5])
                        feature.SetField("heading", row[6])
                        feature.SetField("vertrate", row[7])
                        feature.SetField("callsign", row[8])
                        feature.SetField("onground", row[9])
                        feature.SetField("alert", row[10])
                        feature.SetField("spi", row[11])
                        feature.SetField("squawk", row[12])
                        feature.SetField("baro", row[13])
                        feature.SetField("geo", row[14])
                        feature.SetField("lastpos", row[15])
                        feature.SetField("lastcon", row[16])
                        feature.SetField("hour", row[17])

                        #Create point geometry
                        point = ogr.Geometry(ogr.wkbPoint)
                        point.AddPoint(float(row[4]), float(row[3]))

                        #Create the feature and set the values 
                        feature.SetGeometry(point)
                        layer.CreateFeature(feature)
                        # reset features for next row
                        feature = None
                data_src = None
            ##

# %% [markdown]
# ### Loop for ADSB data downlaod

# %%
from pyopensky import OpenskyImpalaWrapper
from osgeo import ogr
from osgeo import osr
import csv

opensky = OpenskyImpalaWrapper()

for i in range(len(data_DropID)):
    print(i)

    # Perform a query with ICAO filter
    df = opensky.query(
        type="adsb",
        #start="2017-06-01 13:00:00",
        #end="2017-07-01 13:00:10",
        #start="2022-06-01",
        #end="2022-08-01",
        start = datetime1[i],
        end = datetime2[i],
        #[lat1, lon1, lat2, lon2]
        #bound=[data.Longitude1MINUS[i],data.Longitude1PLUS[i],data.Latitude1MINUS[i],data.Latitude1PLUS[i]],
        bound=[dataLatitude1MINUS[i],dataLongitude1MINUS[i],dataLatitude1PLUS[i],dataLongitude1PLUS[i]],
        iaoc24 = ["a07b6a"]
    )
    
    if df is not None:
        #df = df[df["geoaltitude"]<data_ALT[i]]
        
        #df = df[df['lastposupdate'].nunique() > (len(df)-5)]
        if (df['lastposupdate'].nunique() > 25) is not True:
            print("itsnottrue")
        
        
        #df = df[df['geoaltitude']  <  data_ALT[i]]

#         ### FOR SHAPEFILES OF ATUDROP
#         filepathshpATU = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\SHPfromPython\\scratch_2_28_2023\\scratch_2_28_2023_ATUDROP\\"+data_DropID[i]+"_ATUDROP.shp"
#         #filepathcsvATU = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\CSVfromPython\\scratch_2_10_2023_short\\"+data_DropID[i]+"_ATUDROP.csv"
#         driver = ogr.GetDriverByName("ESRI Shapefile")
#         data_src = driver.CreateDataSource(filepathshpATU)
#         srs = osr.SpatialReference()
#         srs.ImportFromEPSG(4326)# 4326 = wgs84
#         layer = data_src.CreateLayer(filepathshpATU, 
#                                          srs, 
#                                          geom_type = ogr.wkbPoint)

#         #Create attribute fields from OpenSky
#         field_name = ogr.FieldDefn("data_DropID", ogr.OFTString)
#         field_name.SetWidth(50)
#         layer.CreateField(field_name)
#         layer.CreateField(ogr.FieldDefn("lon", ogr.OFTReal))
#         layer.CreateField(ogr.FieldDefn("lat", ogr.OFTReal))
#         #layer.CreateField(ogr.FieldDefn("data_DropID", ogr.OFTReal))
       
#         feature = ogr.Feature(layer.GetLayerDefn())
#         feature.SetField("data_DropID", data_DropID[i])
#         feature.SetField("lon", dataLongitude1[i])
#         feature.SetField("lat", dataLatitude1[i])
#         #feature.SetField("data_DropID", data_DropID[i])
                
     
#         #Create point geometry
#         point = ogr.Geometry(ogr.wkbPoint)
#         point.AddPoint(float(dataLongitude1[i]), float(dataLatitude1[i]))

#         #Create the feature and set the values 
#         feature.SetGeometry(point)
#         layer.CreateFeature(feature)
#         # reset features for next row
#         feature = None
#         data_src = None
        
#         ### END SHAPEFILES OF ATUDROP
        
    
        

    if df is not None:
    
        #filepathcsvNA = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\CSVfromPythonwNA\\scratch_2_28_2023\\"+data_DropID[i]+".csv"
        #df.to_csv(filepathcsvNA)

        df2 = df.dropna(subset = ["lat"])          # Apply dropna() function to remove missing lat lon 
        if len(df2) > 0:
            filepathcsv = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\CSVfromPython\\scratch_2_28_2023\\"+data_DropID[i]+".csv"
            df2.to_csv(filepathcsv)
        
            filepathshp = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\SHPfromPython\\scratch_2_28_2023\\"+data_DropID[i]+".shp"
            driver = ogr.GetDriverByName("ESRI Shapefile")
            data_src = driver.CreateDataSource(filepathshp)
            srs = osr.SpatialReference()
            srs.ImportFromEPSG(4326)# 4326 = wgs84
            layer = data_src.CreateLayer(filepathshp, 
                                         srs, 
                                         geom_type = ogr.wkbPoint)

            #Create attribute fields from OpenSky
            field_name = ogr.FieldDefn("time", ogr.OFTString)
            field_name.SetWidth(50)
            layer.CreateField(field_name)
            layer.CreateField(ogr.FieldDefn("lon", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("lat", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("velocity", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("heading", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("vertrate", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("callsign", ogr.OFTString))
            layer.CreateField(ogr.FieldDefn("onground", ogr.OFTString))
            layer.CreateField(ogr.FieldDefn("alert", ogr.OFTString))
            layer.CreateField(ogr.FieldDefn("spi", ogr.OFTString))
            layer.CreateField(ogr.FieldDefn("squawk", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("baro", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("geo", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("lastpos", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("lastcon", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("hour", ogr.OFTString))
    
            with open(filepathcsv, "r") as csv_file:
                csv_reader = csv.reader(csv_file)
                next(csv_reader)
                for row in csv_reader:        
                    feature = ogr.Feature(layer.GetLayerDefn())
                    feature.SetField("time", row[1])
                    feature.SetField("lon", row[4])
                    feature.SetField("lat", row[3])
                    feature.SetField("velocity", row[5])
                    feature.SetField("heading", row[6])
                    feature.SetField("vertrate", row[7])
                    feature.SetField("callsign", row[8])
                    feature.SetField("onground", row[9])
                    feature.SetField("alert", row[10])
                    feature.SetField("spi", row[11])
                    feature.SetField("squawk", row[12])
                    feature.SetField("baro", row[13])
                    feature.SetField("geo", row[14])
                    feature.SetField("lastpos", row[15])
                    feature.SetField("lastcon", row[16])
                    feature.SetField("hour", row[17])
     
                    #Create point geometry
                    point = ogr.Geometry(ogr.wkbPoint)
                    point.AddPoint(float(row[4]), float(row[3]))

                    #Create the feature and set the values 
                    feature.SetGeometry(point)
                    layer.CreateFeature(feature)
                    # reset features for next row
                    feature = None
            data_src = None

# %%
from pyopensky import OpenskyImpalaWrapper
from osgeo import ogr
from osgeo import osr
import csv

# %%
pip install pyopensky

# %% [markdown]
# ## FOR NUMBER 2

# %%
from pyopensky import OpenskyImpalaWrapper
from osgeo import ogr
from osgeo import osr
import csv

opensky = OpenskyImpalaWrapper()

for i in range(len(data_DropID)):
    print(i)

    # Perform a query with ICAO filter
    df = opensky.query(
        type="adsb",
        #start="2017-06-01 13:00:00",
        #end="2017-07-01 13:00:10",
        #start="2022-06-01",
        #end="2022-08-01",
        start = datetime1[i],
        end = datetime2[i],
        #[lat1, lon1, lat2, lon2]
        #bound=[data.Longitude1MINUS[i],data.Longitude1PLUS[i],data.Latitude1MINUS[i],data.Latitude1PLUS[i]],
        bound=[dataLatitude1MINUS[i],dataLongitude1MINUS[i],dataLatitude1PLUS[i],dataLongitude1PLUS[i]]#,
        #iaoc24 = ["a07b6a"]
    )
    
    if df is not None:
        #df = df[df["geoaltitude"]<data_ALT[i]]
        
        #df = df[df['lastposupdate'].nunique() > (len(df)-5)]
        if (df['lastposupdate'].nunique() > (len(df)-5)) is True and (df['icao24'].nunique() == 1) is True and (len(df) >25) is True:
            
            icaocode24 = df['icao24']
            print("itUniqueEnough")
            df2 = df.dropna(subset = ["lat"])          # Apply dropna() function to remove missing lat lon 
            if len(df2) > 0:
                filepathcsv = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\CSVfromPython\\scratch_2_28_2023\\"+data_DropID[i]+".csv"
                df2.to_csv(filepathcsv)
                filepathshp = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\SHPfromPython\\scratch_2_28_2023\\"+data_DropID[i]+".shp"
                driver = ogr.GetDriverByName("ESRI Shapefile")
                data_src = driver.CreateDataSource(filepathshp)
                srs = osr.SpatialReference()
                srs.ImportFromEPSG(4326)# 4326 = wgs84
                layer = data_src.CreateLayer(filepathshp, 
                                             srs, 
                                             geom_type = ogr.wkbPoint)

                #Create attribute fields from OpenSky
                field_name = ogr.FieldDefn("time", ogr.OFTString)
                field_name.SetWidth(50)
                layer.CreateField(field_name)
                layer.CreateField(ogr.FieldDefn("lon", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lat", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("velocity", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("heading", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("vertrate", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("callsign", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("onground", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("alert", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("spi", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("squawk", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("baro", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("geo", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lastpos", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lastcon", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("hour", ogr.OFTString))
    
                with open(filepathcsv, "r") as csv_file:
                    csv_reader = csv.reader(csv_file)
                    next(csv_reader)
                    for row in csv_reader:        
                        feature = ogr.Feature(layer.GetLayerDefn())
                        feature.SetField("time", row[1])
                        feature.SetField("lon", row[4])
                        feature.SetField("lat", row[3])
                        feature.SetField("velocity", row[5])
                        feature.SetField("heading", row[6])
                        feature.SetField("vertrate", row[7])
                        feature.SetField("callsign", row[8])
                        feature.SetField("onground", row[9])
                        feature.SetField("alert", row[10])
                        feature.SetField("spi", row[11])
                        feature.SetField("squawk", row[12])
                        feature.SetField("baro", row[13])
                        feature.SetField("geo", row[14])
                        feature.SetField("lastpos", row[15])
                        feature.SetField("lastcon", row[16])
                        feature.SetField("hour", row[17])

                        #Create point geometry
                        point = ogr.Geometry(ogr.wkbPoint)
                        point.AddPoint(float(row[4]), float(row[3]))

                        #Create the feature and set the values 
                        feature.SetGeometry(point)
                        layer.CreateFeature(feature)
                        # reset features for next row
                        feature = None
                data_src = None
            
            ##
            dfLong = opensky.query(
                type="adsb",
                #start="2017-06-01 13:00:00",
                #end="2017-07-01 13:00:10",
                #start="2022-06-01",
                #end="2022-08-01",
                start = datetime1_2[i],
                end = datetime2_2[i],
                #[lat1, lon1, lat2, lon2]
                #bound=[data.Longitude1MINUS[i],data.Longitude1PLUS[i],data.Latitude1MINUS[i],data.Latitude1PLUS[i]],
                bound=[dataLatitude1MINUS[i],dataLongitude1MINUS[i],dataLatitude1PLUS[i],dataLongitude1PLUS[i]],
                iaoc24 = icaocode24
                )
            
            df2_long = dfLong.dropna(subset = ["lat"])          # Apply dropna() function to remove missing lat lon 
            if len(df2_long) > 0:
                filepathcsv = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\CSVfromPython\\scratch_2_28_2023_2\\"+data_DropID[i]+".csv"
                df2_long.to_csv(filepathcsv)
                filepathshp = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\SHPfromPython\\scratch_2_28_2023_2\\"+data_DropID[i]+".shp"
                driver = ogr.GetDriverByName("ESRI Shapefile")
                data_src = driver.CreateDataSource(filepathshp)
                srs = osr.SpatialReference()
                srs.ImportFromEPSG(4326)# 4326 = wgs84
                layer = data_src.CreateLayer(filepathshp, 
                                             srs, 
                                             geom_type = ogr.wkbPoint)

                #Create attribute fields from OpenSky
                field_name = ogr.FieldDefn("time", ogr.OFTString)
                field_name.SetWidth(50)
                layer.CreateField(field_name)
                layer.CreateField(ogr.FieldDefn("lon", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lat", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("velocity", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("heading", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("vertrate", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("callsign", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("onground", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("alert", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("spi", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("squawk", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("baro", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("geo", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lastpos", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lastcon", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("hour", ogr.OFTString))
    
                with open(filepathcsv, "r") as csv_file:
                    csv_reader = csv.reader(csv_file)
                    next(csv_reader)
                    for row in csv_reader:        
                        feature = ogr.Feature(layer.GetLayerDefn())
                        feature.SetField("time", row[1])
                        feature.SetField("lon", row[4])
                        feature.SetField("lat", row[3])
                        feature.SetField("velocity", row[5])
                        feature.SetField("heading", row[6])
                        feature.SetField("vertrate", row[7])
                        feature.SetField("callsign", row[8])
                        feature.SetField("onground", row[9])
                        feature.SetField("alert", row[10])
                        feature.SetField("spi", row[11])
                        feature.SetField("squawk", row[12])
                        feature.SetField("baro", row[13])
                        feature.SetField("geo", row[14])
                        feature.SetField("lastpos", row[15])
                        feature.SetField("lastcon", row[16])
                        feature.SetField("hour", row[17])

                        #Create point geometry
                        point = ogr.Geometry(ogr.wkbPoint)
                        point.AddPoint(float(row[4]), float(row[3]))

                        #Create the feature and set the values 
                        feature.SetGeometry(point)
                        layer.CreateFeature(feature)
                        # reset features for next row
                        feature = None
                data_src = None
            ##

# %%
datetime2[1]

# %% [markdown]
# ### ALLADSB

# %%
icao24ALL=["a0000c",
"a0000c",
"a00023",
"a00023",
"a00352",
"a00352",
"a003d8",
"a003d8",
"a003d8",
"a004eb",
"a004eb",
"a004eb",
"a00996",
"a00996",
"a00996",
"a00ac9",
"a00ac9",
"a00ac9",
"a00b24",
"a00b24",
"a00b24",
"a00bdc",
"a00bdc",
"a00bdc",
"a00d9f",
"a00d9f",
"a00d9f",
"a00df0",
"a00df0",
"a00df0",
"a00fea",
"a00fea",
"a00fea",
"a011d0",
"a011d0",
"a011d0",
"a011d0",
"a011d0",
"a013b5",
"a013b5",
"a013b5",
"a01471",
"a01471",
"a01471",
"a01663",
"a01663",
"a01663",
"a01717",
"a01717",
"a01717",
"a01b0a",
"a01b0a",
"a01b0a",
"a01b8c",
"a01b8c",
"a01b8c",
"a01bc9",
"a01bc9",
"a01bc9",
"a01d3d",
"a01d3d",
"a01d3d",
"a01ed6",
"a01ed6",
"a01ed6",
"a01ed6",
"a01ed6",
"a01ed6",
"a01ee6",
"a01ee6",
"a01ee6",
"a01eef",
"a01eef",
"a01eef",
"a020f4",
"a020f4",
"a020f4",
"a020f4",
"a020f4",
"a020f4",
"a02175",
"a02175",
"a0218b",
"a0218b",
"a0218b",
"a021e6",
"a021e6",
"a021e6",
"a02232",
"a02232",
"a02232",
"a02234",
"a02234",
"a02234",
"a023a9",
"a023a9",
"a023a9",
"a023fd",
"a023fd",
"a023fd",
"a02460",
"a02460",
"a02460",
"a02504",
"a02504",
"a02504",
"a02585",
"a02585",
"a02585",
"a025e9",
"a025e9",
"a025e9",
"a02737",
"a02737",
"a02737",
"a02862",
"a02862",
"a02862",
"a02862",
"a02862",
"a02862",
"a028ac",
"a028ac",
"a028ac",
"C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\CSVfromPython\\scratch_1_20_2023\\"+data_DropID[i]+".csv"
            df2.to_csv(filepathcsv)
        
            filepathshp = "C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\SHPfromPython\\scratch_1_20_2023\\"+data_DropID[i]+".shp"
            driver = ogr.GetDriverByName("ESRI Shapefile")
            data_src = driver.CreateDataSource(filepathshp)
            srs = osr.SpatialReference()
            srs.ImportFromEPSG(4326)# 4326 = wgs84
            layer = data_src.CreateLayer(filepathshp, 
                                         srs, 
                                         geom_type = ogr.wkbPoint)

            #Create attribute fields from OpenSky
            field_name = ogr.FieldDefn("time", ogr.OFTString)
            field_name.SetWidth(50)
            layer.CreateField(field_name)
            layer.CreateField(ogr.FieldDefn("lon", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("lat", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("velocity", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("heading", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("vertrate", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("callsign", ogr.OFTString))
            layer.CreateField(ogr.FieldDefn("onground", ogr.OFTString))
            layer.CreateField(ogr.FieldDefn("alert", ogr.OFTString))
            layer.CreateField(ogr.FieldDefn("spi", ogr.OFTString))
            layer.CreateField(ogr.FieldDefn("squawk", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("baro", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("geo", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("lastpos", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("lastcon", ogr.OFTReal))
            layer.CreateField(ogr.FieldDefn("hour", ogr.OFTString))
    
            with open(filepathcsv, "r") as csv_file:
                csv_reader = csv.reader(csv_file)
                next(csv_reader)
                for row in csv_reader:        
                    feature = ogr.Feature(layer.GetLayerDefn())
                    feature.SetField("time", row[1])
                    feature.SetField("lon", row[4])
                    feature.SetField("lat", row[3])
                    feature.SetField("velocity", row[5])
                    feature.SetField("heading", row[6])
                    feature.SetField("vertrate", row[7])
                    feature.SetField("callsign", row[8])
                    feature.SetField("onground", row[9])
                    feature.SetField("alert", row[10])
                    feature.SetField("spi", row[11])
                    feature.SetField("squawk", row[12])
                    feature.SetField("baro", row[13])
                    feature.SetField("geo", row[14])
                    feature.SetField("lastpos", row[15])
                    feature.SetField("lastcon", row[16])
                    feature.SetField("hour", row[17])
     
                    #Create point geometry
                    point = ogr.Geometry(ogr.wkbPoint)
                    point.AddPoint(float(row[4]), float(row[3]))

                    #Create the feature and set the values 
                    feature.SetGeometry(point)
                    layer.CreateFeature(feature)
                    # reset features for next row
                    feature = None
            data_src = None

# %%
        # icao24=["a003d8",	"a00996",	"a00d9f",	"a00df0",	"a011d0",	"a01663",	"a01717",	"a01b0a",	"a01bc9",	"a01d3d",	"a01ee6",
        #         "a01eef",	"a020f4",	"a0218b",	"a021e6",	"a02232",	"a02234",	"a02460",	"a02504",	"a02585",	"a025e9",	"a02737",
        #         "a02862",	"a028ac",	"a028af",	"a02ac9",	"a02cb3",	"a02eff",	"a02f59",	"a02f8e",	"a02fbe",	"a03045",	"a030f1",
        #         "a037d9",	"a03b8f",	"a03b90",	"a03ec5",	"a0427c",	"a0441d",	"a04600",	"a04640",	"a0468f",	"a047d2",	"a047d4",
        #         "a04b00",	"a04b89",	"a04f40",	"a05158",	"a05213",	"a0521e",	"a054ad",	"a0554a",	"a056e3",	"a05a76",	"a05b11",
        #         "a05b4b",	"a05ba0",	"a06299",	"a0630e",	"a0633d",	"a06682",	"a06aa7",	"a071ea",	"a07655",	"a078ea",	"a0795d",
        #         "a080a9",	"a082af",	"a082c0",	"a08852",	"a08de5",	"a08e0f",	"a0919c",	"a09451",	"a09501",	"a09553",	"a0a10e",
        #         "a0a11c",	"a0a152",	"a0a328",	"a0a6e5",	"a0a818",	"a0aa23",	"a0ab32",	"a0af73",	"a0af86",	"a0b0ea",	"a0b1ad",
        #         "a0b2a0",	"a0b657",	"a0b6f4",	"a0baab",	"a0be62",	"a0c219",	"a0c5d0",	"a0c89b",	"a0c8d1",	"a0cae6",	"a0cafb",
        #         "a0d19c",	"a0d90e",	"a0dabf",	"a0e77d",	"a0e7ea",	"a0eba1",	"a0f005",	"a0f01a",	"a0f112",	"a0f2a9",	"a0f346",
        #         "a0f4fc",	"a0f59e",	"a0f647",	"a0fcd6",	"a1008d",	"a10853",	"a10bba",	"a10e6c",	"a115d4",	"a11759",	"a11799",
        #         "a117cf",	"a11ce7",	"a1209e",	"a123c7",	"a12455",	"a12473",	"a12f7a",	"a136e8",	"a13a9f",	"a13f4e",	"a14577",
        #         "a14c8f",	"a14d65",	"a14fc2",	"a1511c",	"a15379",	"a154d3",	"a1588a",	"a15ae7",	"a15e9e",	"a1621e",	"a165f3",
        #         "a16865",	"a16926",	"a16c1c",	"a16d79",	"a16fd3",	"a1735b",	"a1770a",	"a17741",	"a17e23",	"a1801f",	"a1869e",
        #         "a189b7",	"a18a1d",	"a18d63",	"a18dd6",	"a18fbc",	"a1906f",	"a190f5",	"a191b5",	"a19700",	"a1993a",	"a19b71",
        #         "a19d62",	"a19dd8",	"a19e6e",	"a19f99",	"a1a0f3",	"a1a119",	"a1a225",	"a1a4b3",	"a1a4b7",	"a1a4c1",	"a1a4d6",
        #         "a1a4f8",	"a1a517",	"a1a554",	"a1a588",	"a1a59c",	"a1a5dc",	"a1a5ed",	"a1a60d",	"a1a615",	"a1a62a",	"a1a649",
        #         "a1a674",	"a1a692",	"a1a69f",	"a1a85b",	"a1a86b",	"a1a883",	"a1a8eb",	"a1a96e",	"a1a993",	"a1a99d",	"a1a9d9",
        #         "a1a9de",	"a1a9e4",	"a1aab2",	"a1ac3e",	"a1ac44",	"a1affb",	"a1b109",	"a1b3b2",	"a1b4b8",	"a1b4c0",	"a1ba96",
        #         "a1c0f8",	"a1c11b",	"a1c1ad",	"a1c1d2",	"a1c236",	"a1c2a1",	"a1c2ce",	"a1c44e",	"a1c589",	"a1c63b",	"a1c877",
        #         "a1c940",	"a1ca0f",	"a1cbf1",	"a1ccb3",	"a1ccf7",	"a1d006",	"a1d06a",	"a1d11a",	"a1d386",	"a1d4d1",	"a1d73d",
        #         "a1d7d8",	"a1df0d",	"a1dffb",	"a1e55c",	"a1e582",	"a1e91f",	"a1ece7",	"a1ef73",	"a1fac6",	"a1fad1",	"a2032a",
        #         "a20331",	"a205da",	"a20db9",	"a210a8",	"a2137e",	"a213c0",	"a2177d",	"a218a9",	"a21ec9",	"a22284",	"a222ab",
        #         "a222bb",	"a22672",	"a229c5",	"a22a29",	"a22f63",	"a233f0",	"a23434",	"a2378e",	"a237a7",	"a23b27",	"a24243",
        #         "a2424a",	"a242cc",	"a2454e",	"a24683",	"a24a03",	"a24cda",	"a255c3",	"a255ea",	"a267f6",	"a27d69",	"a27dcb",
        #         "a28220",	"a28729",	"a299e0",	"a2a063",	"a2a4e8",	"a2bc47",	"a2c15f",	"a2c346",	"a2c3df",	"a2c825",	"a2cc5a",
        #         "a2cc67",	"a2d941",	"a2e1ad",	"a2e4db",	"a2ebed",	"a2f72b",	"a2fd09",	"a3019f",	"a3090d",	"a31894",	"a31fca",
        #         "a32343",	"a3238a",	"a323c6",	"a32741",	"a32a80",	"a32af8",	"a32bc0",	"a32eaf",	"a32f49",	"a33266",	"a33300",
        #         "a3361d",	"a3362e",	"a336b7",	"a3372e",	"a33a6e",	"a33ae5",	"a33e25",	"a33e9c",	"a341dc",	"a3448a",	"a34499",
        #         "a34533",	"a34593",	"a34f21",	"a34f5a",	"a355ac",	"a356c8",	"a3597d",	"a3599e",	"a35afc",	"a35d53",	"a35e1d",
        #         "a35e36",	"a361d4",	"a363a6",	"a365a3",	"a3670a",	"a36b2b",	"a36bf6",	"a36c09",	"a36cbc",	"a385b5",	"a3896c",
        #         "a38b85",	"a38b87",	"a38b8d",	"a38d23",	"a3938e",	"a3943b",	"a394c9",	"a39697",	"a3969d",	"a3b588",	"a3b93f",
        #         "a3bbba",	"a3bf4f",	"a3c306",	"a3c872",	"a3ca74",	"a3d1e2",	"a3e339",	"a3e580",	"a3e5f5",	"a3e5fc",	"a3e65f",
        #         "a3e677",	"a3e6b8",	"a3e8be",	"a3e916",	"a3ecb3",	"a3edb2",	"a3edcc",	"a3ede5",	"a3ede7",	"a3f056",	"a3f06a",
        #         "a3f0ca",	"a3f10d",	"a3f18a",	"a3f24a",	"a3f40d",	"a3f4a4",	"a3f541",	"a3fc11",	"a40078",	"a406b4",	"a407e6",
        #         "a4099b",	"a409b0",	"a40c86",	"a40f42",	"a4106f",	"a42b4a",	"a42dd8",	"a42f42",	"a42f6c",	"a43237",	"a434fa",
        #         "a4391a",	"a459b6",	"a45a05",	"a46099",	"a46807",	"a46b39",	"a47252",	"a4765e",	"a47a15",	"a47f8d",	"a47fc4",
        #         "a48030",	"a48135",	"a488f2",	"a48b4a",	"a48b74",	"a48f2b",	"a492b8",	"a4966f",	"a49e07",	"a4a0ed",	"a4a194",
        #         "a4a4a4",	"a4a9ac",	"a4aa13",	"a4ab0d",	"a4b061",	"a4b116",	"a4b6b1",	"a4b7cb",	"a4bade",	"a4bb24",	"a4bb86",
        #         "a4bc4d",	"a4bd71",	"a4bf39",	"a4c03c",	"a4c082",	"a4c0ab",	"a4c2fc",	"a4c439",	"a4c6d7",	"a4c6dc",	"a4c6e2",
        #         "a4c786",	"a4c7a4",	"a4c7b8",	"a4c7bd",	"a4c7c7",	"a4c7e8",	"a4c7f0",	"a4c821",	"a4c824",	"a4c84f",	"a4c858",
        #         "a4c962",	"a4c964",	"a4c98b",	"a4ca8e",	"a4cb3d",	"a4cba7",	"a4cd6b",	"a4cf5e",	"a4d28c",	"a4d7dd",	"a4d984",
        #         "a4dc79",	"a4dc89",	"a4dcc8",	"a4dce1",	"a4e2c1",	"a4e2fb",	"a4f2ef",	"a4f436",	"a4fc17",	"a4fd21",	"a50085",
        #         "a5065f",	"a5099f",	"a50a26",	"a50ddc",	"a5218a",	"a521d9",	"a533ab",	"a54ed2",	"a55a5c",	"a56aad",	"a56d86",
        #         "a56ee3",	"a57c91",	"a57cfa",	"a58f3c",	"a58fd7",	"a59009",	"a59276",	"a59626",	"a59d87",	"a59f5d",	"a5a13e",
        #         "a5a314",	"a5a6cb",	"a5aa82",	"a5bdc9",	"a5c50b",	"a5c8c2",	"a5cc79",	"a5d1a7",	"a5e754",	"a5e761",	"a5e9be",
        #         "a5eca1",	"a5f1b9",	"a60650",	"a606a2",	"a60a59",	"a60ed3",	"a61069",	"a611a9",	"a61420",	"a61b8e",	"a61f45",
        #         "a622fc",	"a6269c",	"a626b3",	"a62a6a",	"a62cf5",	"a62e21",	"a62f27",	"a631d8",	"a63a5c",	"a63a5e",	"a63b1f",
        #         "a63c4f",	"a63c75",	"a63d43",	"a63e11",	"a6406f",	"a6420f",	"a6421c",	"a64936",	"a64e8c",	"a65695",	"a662bd",
        #         "a66378",	"a664e4",	"a66a2b",	"a66a87",	"a66bf3",	"a66f68",	"a66f8c",	"a678b8",	"a68040",	"a6834a",	"a68361",
        #         "a68694",	"a686ad",	"a695c0",	"a6a060",	"a6a9d9",	"a6abf5",	"a6acee",	"a6b152",	"a6c007",	"a6cd42",	"a6cfd2",
        #         "a6d5ab",	"a6dc21",	"a6ead0",	"a6fadd",	"a703e0",	"a7067c",	"a724a9",	"a724b2",	"a72aaa",	"a72c34",	"a72dc2",
        #         "a72e61",	"a742cc",	"a74412",	"a74cf2",	"a74e6e",	"a753b3",	"a75d35",	"a76043",	"a76063",	"a76595",	"a772dd",
        #         "a772fc",	"a77300",	"a77397",	"a773a7",	"a77447",	"a77780",	"a77c9c",	"a77d4c",	"a783ee",	"a7875d",	"a7880f",
        #         "a7af01",	"a7afb2",	"a7b31d",	"a7b341",	"a7b68e",	"a7c2b1",	"a7c341",	"a7c509",	"a7c634",	"a7cb98",	"a7cc8f",
        #         "a7cdb1",	"a7de35",	"a7e75f",	"a7eb20",	"a7eb97",	"a7eba5",	"a7ed0b",	"a7eda6",	"a7edb3",	"a7f0c7",	"a7f2b1",
        #         "a7f668",	"a7f7d6",	"a7fa1f",	"a7fc9a",	"a7fca7",	"a7fd99",	"a7fdd6",	"a7fe51",	"a8011d",	"a8018d",	"a808c2",
        #         "a808fb",	"a80c79",	"a80cb2",	"a80ef2",	"a814a1",	"a81532",	"a81b8c",	"a81ef2",	"a822a9",	"a822ab",	"a822ab",
        #         "a82555",	"a8290c",	"a82c86",	"a82cc3",	"a837ab",	"a83c14",	"a83cb1",	"a84071",	"a846bc",	"a84a73",	"a84a74",
        #         "a84e2a",	"a84f80",	"a8547b",	"a85598",	"a85f05",	"a863fd",	"a86430",	"a8664f",	"a88baf",	"a89121",	"a893a5",
        #         "a8a4b8",	"a8aa75",	"a8ab22",	"a8b298",	"a8bc56",	"a8d092",	"a8d122",	"a8d145",	"a8d493",	"a8d5ab",	"a8d657",
        #         "a8d68b",	"a8daad",	"a8e696",	"a8ec45",	"a8effc",	"a8f3b3",	"a900dd",	"a9022c",	"a912c2",	"a913ab",	"a92555",
        #         "a929a8",	"a943ae",	"a94778",	"a9485a",	"a94da4",	"a95090",	"a95282",	"a954fa",	"a960ed",	"a96d4f",	"a9738f",
        #         "a97906",	"a97a6f",	"a97e05",	"a98062",	"a980f9",	"a982dc",	"a9848e",	"a98991",	"a98f61",	"a99318",	"a99a63",
        #         "a99a86",	"a99adc",	"a99ae0",	"a99e3d",	"a9a08c",	"a9a44d",	"a9abbb",	"a9ac00",	"a9b2a2",	"a9b6e0",	"a9ba97",
        #         "a9c96a",	"a9fefc",	"aa0632",	"aa4249",	"aa4cb2",	"aa5c38",	"aa743c",	"aa7f72",	"aa849e",	"aa84b5",	"aa8e56",
        #         "aa8e94",	"aa9307",	"aaac27",	"aab63f",	"aac034",	"aac3eb",	"aacb59",	"aaddc9",	"aaded5",	"aae0b8",	"aae234",
        #         "aae5d1",	"aaea99",	"aaeafc",	"aaee50",	"aaf207",	"aaf9b9",	"aafcb7",	"aaffb6",	"ab0df5",	"ab11cc",	"ab1d90",
        #         "ab1eff",	"ab282a",	"ab2ea3",	"ab3076",	"ab3b9f",	"ab4c04",	"ab4f43",	"ab62a2",	"ab6e40",	"ab6fea",	"ab7758",
        #         "ab7dbc",	"aba64d",	"aba652",	"aba6ab",	"abb067",	"abb6e3",	"abc18d",	"abd532",	"abde62",	"abe5d0",	"abed3e",
        #         "ac0235",	"ac54df",	"ac54e0",	"ac6aff",	"ac6bc8",	"ac6faf",	"ac6fe3",	"ac7622",	"ac7706",	"ac7811",	"ac7859",
        #         "ac7a29",	"ac7cc3",	"ac8158",	"ac85b0",	"ac894e",	"ac8967",	"ac95fc",	"ac96d4",	"ac9896",	"ac9aa8",	"ac9af0",
        #         "ac9b1e",	"ac9b26",	"ac9b51",	"ac9b58",	"ac9c2c",	"ac9c4d",	"ac9c63",	"ac9d8a",	"ac9e06",	"ac9ed4",	"ac9f0f",
        #         "aca0ac",	"aca0cf",	"aca12c",	"aca352",	"acbd1f",	"acbf00",	"acc626",	"acd550",	"acdb5b",	"acdc20",	"ace3a1",
        #         "acf108",	"acf876",	"ad2763",	"ad2b1a",	"ad2ed1",	"ad33e8",	"ad3535",	"ad4eab",	"ad5418",	"ad5a34",	"ad72fe",
        #         "ad80d4",	"ad829a",	"ad8556",	"ad8556",	"ad878a",	"ad8be2",	"ad9330",	"ad97b7",	"ad9de0",	"ada693",	"adaa0c",
        #         "adaa79",	"adb7c8",	"adc6bb",	"adc8f5",	"adea36",	"adec58",	"adef02",	"adf1f3",	"adf349"],#722 vs 721  a99a63

# %% [markdown]
# ### 3_31_2023

# %%
IAOC24_CODES = ["C00E3E","C07CB2","A7D27A","A69072","A11CBB","A7F642","A9926A","AB79CC","A3F3AC","A3F763","A442AA","A85052",
                "A4EA6D","A380E6","A4B460","A47CBC","A48A3A","A47197","A46DE0","A4C031","A07F21",
               "A380E6","A4B50C","A0956B","A2F996","A2FD4D","A30104","A304BB","A30872","A46DE0","A47CBC","A48A3A","A47197",
                "A5CD6C","A5D123","A5D4DA","AD66E3","ADC0C4","AAFD0B","A5C9B5","A8215E","A19DA0", "A2B7FD"]

IAOC24_CODES = [code.lower() for code in IAOC24_CODES]
print(IAOC24_CODES)
print(len(IAOC24_CODES))
# Out:
# ['c00e3e', 'c07cb2', 'a7d27a', 'a69072', 'a11cbb', 'a7f642', 'a9926a', 'ab79cc', 'a3f3ac', 'a3f763', 'a442aa', 'a85052', 'a4ea6d', 'a380e6', 'a4b460', 'a47cbc', 'a48a3a', 'a47197', 'a46de0', 'a4c031', 'a07f21', 'a380e6', 'a4b50c', 'a0956b', 'a2f996', 'a2fd4d', 'a30104', 'a304bb', 'a30872', 'a46de0', 'a47cbc', 'a48a3a', 'a47197', 'a5cd6c', 'a5d123', 'a5d4da', 'ad66e3', 'adc0c4', 'aafd0b', 'a5c9b5', 'a8215e', 'a19da0', 'a2b7fd']
# 43

# %%
#IAOC24_CODES

# %%
from datetime import datetime
from datetime import datetime, timedelta
import pandas as pd
#data = pd.read_csv("C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\ATU_2017_2021_ALL_WGS.txt", sep=",", header=0)

data = pd.read_csv("C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\ATUData\\ATU_2017_2021_1mile_ALL.txt", sep=",", header=0)

#data = pd.read_csv("C:\\Users\\admin-magstadt\\Desktop\\ADSB_data\\ATUData\\ATU_2017_2021_ALL_WGS_500AGL.txt", sep=",", header=0)

#"C:\Users\magst\Desktop\NorCalATUpts\ATU_2017_2021_ALL_WGS_500AGL.txt"

print(list(data.columns))
print(len(data))
# Out:
# ['OID_', 'Drop_ID1', 'Vendor1', 'FalsePos1', 'SplitDrop1', 'Latitude1', 'Longitude1', 'LocalDate1', 'LocalHour1', 'Knots1', 'HdingTrue1', 'AltFeet1', 'LocalTZ1', 'Gallons1', 'Tail_Numbe', 'UTCdateTim', 'localMonth', 'localDay1', 'localYear1', 'LineLenMi1', 'IncName1', 'IncNum1', 'IADrop1', 'AC_Type1', 'Fluid1', 'NONFIRE1', 'Shape_Leng', 'DropMinute', 'DropSecond', 'Shape_Le_1']
# 63668

# %%
import pandas as pd

# Read the dataset into a pandas dataframe
data 

# Group the data by "Tail_Numbe" and get the unique values
unique_tail_numbers = data.groupby("Tail_Numbe").size().reset_index(name="Count")

# Print the unique tail numbers and their associated count
print(unique_tail_numbers)
# Out:
#    Tail_Numbe  Count
# 0   DZM441434    194
# 1      N130CG    326
# 2        T-01   1928
# 3        T-02    819
# 4        T-03   1943
# 5        T-05    166
# 6        T-06    161
# 7        T-07     69
# 8        T-10   1097
# 9       T-101   1088
# 10      T-102    923
# 11      T-103    761
# 12      T-104    619
# 13      T-105   1085
# 14      T-107    673
# 15       T-12   1520
# 16      T-131   2064
# 17      T-132    573
# 18      T-133    391
# 19      T-137    874
# 20       T-14    204
# 21      T-142    228
# 22       T-15   1175
# 23      T-152    115
# 24       T-16   1503
# 25      T-160   1619
# 26      T-161    664
# 27      T-162   1591
# 28      T-163   1405
# 29      T-164   1365
# 30      T-166    275
# 31      T-167   1646
# 32      T-168   1042
# 33      T-169    469
# 34      T-210    177
# 35      T-260   4753
# 36      T-261   6210
# 37      T-262   6001
# 38      T-263   4748
# 39       T-40   1978
# 40       T-41   2088
# 41       T-44    184
# 42      T-910   1818
# 43      T-911   2000
# 44      T-912   1653
# 45      T-914   1345
# 46      T-944    138

# %%
# Define the function to map tail numbers to ADSB codes
def map_tail_number_to_adsb_code(tail_number):
    if tail_number == "T-01":
        return "a5cd6c"
    elif tail_number == "T-02":
        return "a5d123"
    elif tail_number == "T-03":
        return "a5d4da"
    elif tail_number == "T-05":
        return "ad66e3"
    elif tail_number == "T-06":
        return "adc0c4"
    elif tail_number == "T-07":
        return "aafd0b"
    elif tail_number == "T-10":
        return "a5c9b5"
    elif tail_number == "T-101":
        return "a2f996"
    elif tail_number == "T-102":
        return "a2fd4d"
    elif tail_number == "T-103":
        return "a30104"
    elif tail_number == "T-104":
        return "a304bb"
    elif tail_number == "T-105":
        return "a30872"
    elif tail_number == "T-107":
        return "a30fe0"
    elif tail_number == "T-12":
        return "a5d891"
    elif tail_number == "T-131":
        return "a07f21"
    elif tail_number == "T-132":
        return "a4c031"
    elif tail_number == "T-133":
        return "a4b50c"
    elif tail_number == "T-137":
        return "a0956b"
    elif tail_number == "T-14":
        return "a8215e"
    elif tail_number == "T-142":
        return "a19da0"
    elif tail_number == "T-15":
        return "a2b7fd"
    elif tail_number == "T-152":
        return "ac75f9"
    elif tail_number == "T-16":
        return "a5dfff"
    elif tail_number == "T-160":
        return "ab79cc"
    elif tail_number == "T-161":
        return "a3f3ac"
    elif tail_number == "T-162":
        return "a3f763"
    elif tail_number == "T-163":
        return "a42299"
    elif tail_number == "T-164":
        return "a442aa"
    elif tail_number == "T-166":
        return "c07cb2"
    elif tail_number == "T-167":
        return "a85052"
    elif tail_number == "T-168":
        return "a4ea6d"
    elif tail_number == "T-169":
        return "a380e6"
    elif tail_number == "T-210":
        return "a4b460"
    elif tail_number == "T-260":
        return "a47cbc"
    elif tail_number == "T-261":
        return "a48a3a"
    elif tail_number == "T-262":
        return "a47197"
    elif tail_number == "T-263":
        return "a46de0"
    elif tail_number == "T-40":
        return "A9A086"
    elif tail_number == "T-41":
        return "NA"
    elif tail_number == "T-44":
        return "c00e3e"
    elif tail_number == "T-910":
        return "a7f642"
    elif tail_number == "T-911":
        return "a11cbb"
    elif tail_number == "T-912":
        return "a69072"
    elif tail_number == "T-914":
        return "a7d27a"
    elif tail_number == "T-944":
        return "NA"
    elif tail_number == "N130CG":
        return "a07b6a"
    else:    
        return "UNKNOWN_ADSB_CODE"

# Create a new column "adsbCODE" based on the values in the "Tail_Numbe" column
data["adsbCODE"] = data["Tail_Numbe"].apply(lambda x: map_tail_number_to_adsb_code(x))

# %%
adsbCODES = data["adsbCODE"]
adsbCODES[23]
# Out:
# 'a5cd6c'

# %%
data.UTCdateTim = data.UTCdateTim.str[:-4]
#data['UTCdateTim'] = df['UTCdateTim'].str.slice(stop=-9)

# this is nice
#prefixes = ['N130CG', 'N131CG', 'N132CG', 'N137CG', 'N293EA', 'N292EA', 'N294EA', 'N295EA', 'N297EA','N291EA','N138CG']
#data = data[data['Drop_ID1'].str.startswith(tuple(prefixes))]

#data = data[data['Drop_ID1'].str.startswith('N130CG')]
#data = data[data['Drop_ID1'].str.startswith('N130CG')]
#data = data[data['Drop_ID1'].str.startswith('N130CG')]

#print(data.UTCdateTim)
data['UTCdateTim']= pd.to_datetime(data['UTCdateTim'])
#data.UTCdateTime2 = datetime.data.UTCdateTim

time_change = timedelta(minutes=0.25)
data["Time2"] = data.UTCdateTim + time_change
data["Time1"] = data.UTCdateTim - time_change

time_change2 = timedelta(minutes=3.25)
data["Time2_2"] = data.UTCdateTim + time_change2
data["Time1_2"] = data.UTCdateTim - time_change2

# time_change = timedelta(minutes=0.25)
# data["Time2"] = data.UTCdateTim - time_change
# data["Time1"] = data.UTCdateTim - time_change*3

# time_change2 = timedelta(minutes=2.5)
# data["Time2_2"] = data.UTCdateTim - time_change
# data["Time1_2"] = data.UTCdateTim - time_change*3

# data["Latitude1PLUS"] = data.Latitude1+0.02
# data["Latitude1MINUS"] = data.Latitude1-0.02

# data["Longitude1PLUS"] = data.Longitude1+0.02
# data["Longitude1MINUS"] = data.Longitude1-0.02

data["Latitude1PLUS"] = data.Latitude1+0.02
data["Latitude1MINUS"] = data.Latitude1-0.02

data["Longitude1PLUS"] = data.Longitude1+0.02
data["Longitude1MINUS"] = data.Longitude1-0.02

dataLatitude1PLUS =data["Latitude1PLUS"].tolist()
dataLatitude1MINUS =data["Latitude1MINUS"].tolist()

dataLongitude1PLUS =data["Longitude1PLUS"].tolist()
dataLongitude1MINUS =data["Longitude1MINUS"].tolist()

dataLongitude1 =  data.Longitude1.tolist()
dataLatitude1 = data.Latitude1.tolist()

#data.head()
#print(data.columns)
datetime1 = data.Time1.tolist()
datetime2 = data.Time2.tolist()

datetime1_2 = data.Time1_2.tolist()
datetime2_2 = data.Time2_2.tolist()

import pandas as pd
import numpy as np
data=data.replace(regex=[':'], value='_')
data=data.replace(regex=['-'], value='_')
data=data.replace(regex=[' '], value='')

#data
data_DropID = data.Drop_ID1.tolist()
#data_DropID


data["AltMeter1"] = data["AltFeet1"]*0.3048
data_ALT = data["AltMeter1"]+200
data_ALT = data_ALT.tolist()
len(data)
# Out:
# 63668

# %%
from pyopensky import OpenskyImpalaWrapper
from osgeo import ogr
from osgeo import osr
import csv

opensky = OpenskyImpalaWrapper()

for i in range(len(data_DropID)):
    print(i)
    

    # Perform a query with ICAO filter
    df = opensky.query(
        type="adsb",
        #start="2017-06-01 13:00:00",
        #end="2017-07-01 13:00:10",
        #start="2022-06-01",
        #end="2022-08-01",
        start = datetime1[i],
        end = datetime2[i],
        #[lat1, lon1, lat2, lon2]
        #bound=[data.Longitude1MINUS[i],data.Longitude1PLUS[i],data.Latitude1MINUS[i],data.Latitude1PLUS[i]],
        bound=[dataLatitude1MINUS[i],dataLongitude1MINUS[i],dataLatitude1PLUS[i],dataLongitude1PLUS[i]],
        #icao24 = ["a07b6a"]
        icao24 = adsbCODES[i]#IAOC24_CODES#['c00e3e', 'c07cb2', 'a7d27a', 'a69072', 'a11cbb', 'a7f642', 'a9926a', 'ab79cc', 'a3f3ac', 'a3f763', 'a442aa', 'a85052', 'a4ea6d', 'a380e6', 'a4b460', 'a47cbc', 'a48a3a', 'a47197', 'a46de0', 'a4c031', 'a07f21', 'a380e6', 'a4b50c', 'a0956b', 'a2f996', 'a2fd4d', 'a30104', 'a304bb', 'a30872', 'a46de0', 'a47cbc', 'a48a3a', 'a47197', 'a5cd6c', 'a5d123', 'a5d4da', 'ad66e3', 'adc0c4', 'aafd0b', 'a5c9b5', 'a8215e', 'a19da0', 'a2b7fd']
    )
    
    if df is not None:
        #df = df[df["geoaltitude"]<data_ALT[i]]
        
        #df = df[df['lastposupdate'].nunique() > (len(df)-5)]
        #if (df['lastposupdate'].nunique() > (len(df)-9)) is True and (df['icao24'].nunique() == 1) is True and (len(df) > 25) is True:
        if (df['lastposupdate'].nunique() > (len(df)-15)) is True and (df['icao24'].nunique() == 1) is True and (len(df) > 25) is True:

        #if (df['icao24'].nunique() == 1) is True:

            icaocode24 = df['icao24']
            print("itUniqueEnough")
            df2 = df.dropna(subset = ["lat"])          # Apply dropna() function to remove missing lat lon 
            if len(df2) > 0:
                filepathcsv = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\"+data_DropID[i]+".csv"
                df2.to_csv(filepathcsv)
                filepathshp = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\"+data_DropID[i]+".shp"
                driver = ogr.GetDriverByName("ESRI Shapefile")
                data_src = driver.CreateDataSource(filepathshp)
                srs = osr.SpatialReference()
                srs.ImportFromEPSG(4326)# 4326 = wgs84
                layer = data_src.CreateLayer(filepathshp, 
                                             srs, 
                                             geom_type = ogr.wkbPoint)

                #Create attribute fields from OpenSky
                field_name = ogr.FieldDefn("time", ogr.OFTString)
                field_name.SetWidth(50)
                layer.CreateField(field_name)
                layer.CreateField(ogr.FieldDefn("lon", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lat", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("velocity", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("heading", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("vertrate", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("callsign", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("onground", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("alert", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("spi", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("squawk", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("baro", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("geo", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lastpos", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lastcon", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("hour", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("icao24", ogr.OFTString))
  
                with open(filepathcsv, "r") as csv_file:
                    csv_reader = csv.reader(csv_file)
                    next(csv_reader)
                    for row in csv_reader:        
                        feature = ogr.Feature(layer.GetLayerDefn())
                        feature.SetField("time", row[1])
                        feature.SetField("lon", row[4])
                        feature.SetField("lat", row[3])
                        feature.SetField("velocity", row[5])
                        feature.SetField("heading", row[6])
                        feature.SetField("vertrate", row[7])
                        feature.SetField("callsign", row[8])
                        feature.SetField("onground", row[9])
                        feature.SetField("alert", row[10])
                        feature.SetField("spi", row[11])
                        feature.SetField("squawk", row[12])
                        feature.SetField("baro", row[13])
                        feature.SetField("geo", row[14])
                        feature.SetField("lastpos", row[15])
                        feature.SetField("lastcon", row[16])
                        feature.SetField("hour", row[17])
                        feature.SetField("icao24", row[2])


                        #Create point geometry
                        point = ogr.Geometry(ogr.wkbPoint)
                        point.AddPoint(float(row[4]), float(row[3]))

                        #Create the feature and set the values 
                        feature.SetGeometry(point)
                        layer.CreateFeature(feature)
                        # reset features for next row
                        feature = None
                data_src = None
            
            ##
            dfLong = opensky.query(
                type="adsb",
                #start="2017-06-01 13:00:00",
                #end="2017-07-01 13:00:10",
                #start="2022-06-01",
                #end="2022-08-01",
                start = datetime1_2[i],
                end = datetime2_2[i],
                #[lat1, lon1, lat2, lon2]
                #bound=[data.Longitude1MINUS[i],data.Longitude1PLUS[i],data.Latitude1MINUS[i],data.Latitude1PLUS[i]],
                #bound=[dataLatitude1MINUS[i],dataLongitude1MINUS[i],dataLatitude1PLUS[i],dataLongitude1PLUS[i]],
                icao24 = icaocode24
                )
            
            df2_long = dfLong.dropna(subset = ["lat"])          # Apply dropna() function to remove missing lat lon 
            if len(df2_long) > 0:
                filepathcsv = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\longerversion\\"+data_DropID[i]+".csv"
                df2_long.to_csv(filepathcsv)
                filepathshp = "C:\\Users\\admin-magstadt\\Desktop\\Data_4_17_2023\\longerversion\\"+data_DropID[i]+".shp"
                driver = ogr.GetDriverByName("ESRI Shapefile")
                data_src = driver.CreateDataSource(filepathshp)
                srs = osr.SpatialReference()
                srs.ImportFromEPSG(4326)# 4326 = wgs84
                layer = data_src.CreateLayer(filepathshp, 
                                             srs, 
                                             geom_type = ogr.wkbPoint)

                #Create attribute fields from OpenSky
                field_name = ogr.FieldDefn("time", ogr.OFTString)
                field_name.SetWidth(50)
                layer.CreateField(field_name)
                layer.CreateField(ogr.FieldDefn("lon", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lat", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("velocity", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("heading", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("vertrate", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("callsign", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("onground", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("alert", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("spi", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("squawk", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("baro", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("geo", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lastpos", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("lastcon", ogr.OFTReal))
                layer.CreateField(ogr.FieldDefn("hour", ogr.OFTString))
                layer.CreateField(ogr.FieldDefn("icao24", ogr.OFTString))

    
                with open(filepathcsv, "r") as csv_file:
                    csv_reader = csv.reader(csv_file)
                    next(csv_reader)
                    for row in csv_reader:        
                        feature = ogr.Feature(layer.GetLayerDefn())
                        feature.SetField("time", row[1])
                        feature.SetField("lon", row[4])
                        feature.SetField("lat", row[3])
                        feature.SetField("velocity", row[5])
                        feature.SetField("heading", row[6])
                        feature.SetField("vertrate", row[7])
                        feature.SetField("callsign", row[8])
                        feature.SetField("onground", row[9])
                        feature.SetField("alert", row[10])
                        feature.SetField("spi", row[11])
                        feature.SetField("squawk", row[12])
                        feature.SetField("baro", row[13])
                        feature.SetField("geo", row[14])
                        feature.SetField("lastpos", row[15])
                        feature.SetField("lastcon", row[16])
                        feature.SetField("hour", row[17])
                        feature.SetField("icao24", row[2])


                        #Create point geometry
                        point = ogr.Geometry(ogr.wkbPoint)
                        point.AddPoint(float(row[4]), float(row[3]))

                        #Create the feature and set the values 
                        feature.SetGeometry(point)
                        layer.CreateFeature(feature)
                        # reset features for next row
                        feature = None
                data_src = None
            ##
# Out:
# * Server connection successful!
# 0
# * Obtaining details of the query...
# * OpenSky Impala: 31 of records found.
# * Fetching records...
# * Records downloaded.
# 1
# * Obtaining details of the query...
# * OpenSky Impala: 31 of records found.
# * Fetching records...
# * Records downloaded.
# 2
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 3
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 4
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 5
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 6
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 7
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 8
# * Obtaining details of the query...
# * OpenSky Impala: 31 of records found.
# * Fetching records...
# * Records downloaded.
# 9
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 10
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 11
# * Obtaining details of the query...
# * OpenSky Impala: 31 of records found.
# * Fetching records...
# * Records downloaded.
# itUniqueEnough
# * Obtaining details of the query...
# * OpenSky Impala: 391 of records found.
# * Fetching records...
# * Records downloaded.
# 12
# * Obtaining details of the query...
# * OpenSky Impala: 31 of records found.
# * Fetching records...
# * Records downloaded.
# itUniqueEnough
# * Obtaining details of the query...
# * OpenSky Impala: 391 of records found.
# * Fetching records...
# * Records downloaded.
# 13
# * Obtaining details of the query...
# * OpenSky Impala: 31 of records found.
# * Fetching records...
# * Records downloaded.
# 14
# * Obtaining details of the query...
# * OpenSky Impala: 31 of records found.
# * Fetching records...
# * Records downloaded.
# itUniqueEnough
# * Obtaining details of the query...
# * OpenSky Impala: 391 of records found.
# * Fetching records...
# * Records downloaded.
# 15
# * Obtaining details of the query...
# * OpenSky Impala: 31 of records found.
# * Fetching records...
# * Records downloaded.
# itUniqueEnough
# * Obtaining details of the query...
# * OpenSky Impala: 391 of records found.
# * Fetching records...
# * Records downloaded.
# 16
# * Obtaining details of the query...
# * OpenSky Impala: 31 of records found.
# * Fetching records...
# * Records downloaded.
# itUniqueEnough
# * Obtaining details of the query...
# * OpenSky Impala: 391 of records found.
# * Fetching records...
# * Records downloaded.
# 17
# * Obtaining details of the query...
# * OpenSky Impala: 31 of records found.
# * Fetching records...
# * Records downloaded.
# 18
# * Obtaining details of the query...
# * OpenSky Impala: 31 of records found.
# * Fetching records...
# * Records downloaded.
# 19
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 20
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 21
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 22
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 23
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 24
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 25
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 26
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 27
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 28
# * Obtaining details of the query...
# * OpenSky Impala: 31 of records found.
# * Fetching records...
# * Records downloaded.
# itUniqueEnough
# * Obtaining details of the query...
# * OpenSky Impala: 391 of records found.
# * Fetching records...
# * Records downloaded.
# 29
# * Obtaining details of the query...
# * OpenSky Impala: 31 of records found.
# * Fetching records...
# * Records downloaded.
# itUniqueEnough
# * Obtaining details of the query...
# * OpenSky Impala: 391 of records found.
# * Fetching records...
# * Records downloaded.
# 30
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 31
# * Obtaining details of the query...
# * OpenSky Impala: 31 of records found.
# * Fetching records...
# * Records downloaded.
# 32
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 33
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 34
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 35
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
# 36
# * Obtaining details of the query...
# * OpenSky Impala: 0 of records found.
# * No record found.
#